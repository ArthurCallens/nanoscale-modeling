# %% [markdown]
# <h1><center>Modelling and Engineering of Nanoscale Materials <br> Exercises session 9: Machine Learning the PES </center></h1>
# <center>massimo.bocus@ugent.be, arnout.maet@ugent.be, thomas.nicholas@ugent.be</center>

# %%
import numpy as np

from time import time

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.saving import load_model
tf.keras.backend.set_floatx('float64')  # keras precision
keras.utils.set_random_seed(0)  # set rng seed
tf.config.optimizer.set_jit(False)

import ase
from ase.visualize import view
from ase.io import read, write

import matplotlib.pyplot as plt

from pyiron import Project, ase_to_pyiron, pyiron_to_ase

from IPython.display import Image
# Out:
# 2025-12-08 18:03:02.305907: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-08 18:03:02.306441: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-08 18:03:02.366045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-08 18:03:21.982042: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-08 18:03:21.985600: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Colors
blue = "#000080"  # dark/navy blue
red = "#8B0000"
green = 'darkgreen'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Educational Objectives</b> <br>
#
# (1)  Create representative datasets to train accurate MLPs <br>
# (2)  Predict ab-initio energies and forces of small molecules using simple neural networks<br>
# (3)  Understand the effects of the presence/absence of physical symmetries in the descriptors of the model <br>
# (4)  Evaluate the accuracy of an MLP <br>
# (5)  Understand interpolation v.s. extrapolation capabilities of simple neural networks <br>
# (6)  Use a self-trained MLP to optimize a water molecule and perform molecular dynamics
# </div>

# %% [markdown]
# # Introduction

# %% [markdown]
# <figure>
# <center><img src="https://www.dropbox.com/scl/fi/wo37pi0um6muhsd294m4e/mlp.png?rlkey=7lk0ds8w8gq3pksrrui05mlh6&st=s5bt6joy&raw=1" width="1000"></center>
# <center><figcaption>Figure 1: Illustration of a general Machine Learning Potential.</figcaption></center>
# </figure>

# %%
# Setting up the project
pr = Project('session9')

# %%
# A general Gaussian job function, this is easy to use for large benchmarks using for-loops
def g16_job(pr, name, jobtype, structure, lot, basis_set, charge=0, multiplicity=1, verbosity='low', settings={}, cluster='donphan', cores=1, run_time=5*60):
    '''
        ***Args***
 
        pr  the pyiron Project in which this job will be classified
 
        name (string)
            the job name, must be unique within this project
 
        jobtype (string)
            job type as defined on the Gaussian16 site: e.g. sp,opt,freq,...
 
        structure
            a pyiron structure object
 
        lot (string)
            a level of theory as defined on the Gaussian16 site
 
        basis_set (string)
            a basis set as defined on the Gaussian16 site
 
        charge (int)
            the charge of the structure
 
        multiplicity (int)
            the spin multiplicity of the structure, 2S+1

        settings (dict)
            dictionary using the following format {'key':['option1','option2',...]} such that
            e.g. the following options "int(grid=ultrafine) SCF=YQC" can be set with
            settings = {'int':['grid=ultrafine'], 'SCF':['YQC']}
 
        cluster (string)
            name of the HPC cluster on which this computation should take place
 
        cores (int)
            the number of cores which should be used (max amount of memory = cores*mem_per_cpu)
 
        run_time (int)
            wall time in seconds (max of 72*60*60)
    '''
 
    job = pr.create_job(pr.job_type.Gaussian, name, delete_existing_job=True)
    job.structure = structure
    ################################
    job.input['jobtype'] = jobtype
    job.input['lot'] = lot
    job.input['basis_set'] = basis_set
    job.input['charge'] = charge
    job.input['spin_mult'] = multiplicity
    job.input['verbosity'] = verbosity
    ################################
    if len(settings)>0:
        job.input['settings'] = settings
        
    job.server.queue = cluster
    job.server.cores = cores
    job.server.run_time = run_time
    job.run()
    # return job # you could return the job object if you want

# %% [markdown]
# # Exercise 1: Generating data sets

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>In short:</b> <br>
#     1. Construct a representative dataset for the water molecule. <br>
#     2. Construct an informative independent test set.
# </div>

# %% [markdown]
# The goal of this exercise session is to build a neural network capable of predicting the ab-initio energy (and forces) of a single water molecule. A neural network takes an input vector, applies a series of linear and nonlinear transformations, and produces one or more output values. These internal transformations are determined by the model’s weights and biases (collectively called the parameters), which control how the numerical values (features) in one layer are mapped to the next.
#
# During training, the network’s parameters are iteratively adjusted so that the model’s outputs match the desired results as closely as possible. Every neural network, from machine-learning potentials (MLPs) to large language models (LLMs) such as ChatGPT, relies on this optimization process to achieve good predictive performance.
#
# In our case, we aim to construct a neural network that can take the geometry of a water molecule and predict its energy (and forces) at a chosen level of theory. To do this, we need a dataset of water configurations labeled with their “correct” ab-initio energies. Neural networks excel at interpolating between data points but perform poorly at extrapolation. This means our training set must adequately cover the region of phase space we intend to explore; if the model encounters configurations outside this region, its predictions will be highly unreliable. Additionally, we will prepare an independent test set to evaluate the accuracy of the trained model.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Answer the following questions using the code below:</b> <br>
# <ol type='1'>
# <li> Create a training set for water at the MP2/6-31g level of theory containing 50 structures. What do you think constitutes a good training set? Visualise your data set by plotting the distribution of the relevant internal coordinates.</li>
# <br>
# <li> Create an independent test set of 50 structures by scanning one of the O-H distances. Make sure that the range of distances goes beyond those present in the training set, such that you can see the extrapolated/interpolated points. What can we learn from this test set?</li>
# <br>
# <li> Why is evaluating the training set not a reliable way to quantify the accuracy of a neural network?</li>
# </ol>
# </div>

# %% [markdown]
# ### Question 1

# %% [markdown]
# Load the optimized water structure from session 1 and create a dataset of $50$ structures by manipulating the optimized structure.
#
# **HINT:** Try to make the dataset sufficiently diverse, the model can not learn anything new from duplicate structures. However, do not make it too diverse as this will make training more difficult.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Data structure</b>
#
# It will be convenient to store the structures and their corresponding energy as a list of `ase.Atoms`-objects:
#
# ```python
# configs = []  # list to store Atoms-objects
#
# job = ex1.load('job')
# structure = job.structure
# energy = job.output.energy_tot[-1]  # extract energy from job
#
# atoms = pyiron_to_ase(structure)
# atoms.info['energy'] = energy  # add energy to Atoms-object
#
# configs.append(atoms))  # add Atoms-object to list
# ```
#
# The energy of `ase.Atoms`-objects can be called as:
#
# ```python
# energy = config.get_potential_energy()
# ```
#
# Lists of `ase.Atoms`-objects can then also be saved to or loaded from disk using the `write`- and `read`-functions:
#
# ```python
# write('path.xyz', configs)
# configs = read('path.xyz', index=':')
# ```
#
# </div>

# %%
ex1 = pr.create_group('ex1')
pr_old = Project('session1')
water_opt =  pr_old.load('h2o_optimized').get_structure() # optimzed water molecule from session 1

# %%
# add code here to manipulate water molecule
def adapt_distance(structure, distance):
    adapted_structure = structure.copy()
    adapted_structure.set_distance(0, 1, distance) # use the appropriate settings
    return adapted_structure 

def adapt_angle(structure, angle_deg):
    adapted_structure = structure.copy()
    adapted_structure.set_angle(1, 0, 2, angle_deg)  # H1-O-H2
    return adapted_structure

# %% [markdown]
# ### Question 1

# %%
# add code here to scan an internal coordinate
start = pyiron_to_ase(water_opt)
d1_opt = start.get_distance(0,1)
d2_opt = start.get_distance(0,2)
ang_opt = start.get_angle(1,0,2)
train_set = []
d1s = []
d2s = []
angs = []
for i in range(50):
    config = start.copy()
    d1 = np.random.normal(d1_opt, 0.15)
    d2 = np.random.normal(d2_opt, 0.15)
    ang = np.random.normal(ang_opt, 20)
    d1s.append(d1)
    d2s.append(d2)
    angs.append(ang)
    config.set_distance(0,1,d1)
    config.set_distance(0,2,d2)
    config.set_angle(1,0,2,ang)
    #structure = ase_to_pyiron(config) # superclass of atoms that pyiron needs for the calculation
    #g16_job(ex1, name=f"struc_{i}", jobtype="sp", structure=structure, lot="MP2", basis_set = "6-31G", cluster="doduo")
    train_set.append(config)
dist1 = np.array(d1s)
dist2 = np.array(d2s)
angles = np.array(angs)
fig, axs = plt.subplots(1,3, figsize=(12,4))
axs[0].set_xlabel("O-H1 distance [Å]")
axs[0].set_ylabel("Count")
axs[0].hist(dist1)
axs[1].hist(dist2)
axs[1].set_xlabel("O-H2 distance [Å]")
axs[2].hist(angles)
axs[2].set_xlabel("H1-O-H2 angle [degrees]")
plt.tight_layout()
plt.show()

# %%
# add code here to evaluate structures
configs = []  
energies = []
for i in range(50):
    job = ex1.load(f"struc_{i}")
    structure = job.structure
    energy = job.output.energy_tot[-1] 
    
    atoms = pyiron_to_ase(structure)
    atoms.info['energy'] = energy  
    
    configs.append(atoms)
write('session9/path.xyz', configs) 
configs = read('session9/path.xyz', index=':')
view(configs, viewer="ngl")
# Out:
# HBox(children=(NGLWidget(max_frame=49), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'),…

# %%
# add code here to save structures as .xyz file
ex1.job_table()
# Out:
#        id    status chemicalformula                           job  \
# 0    1587  finished             H2O                 struc_100_0d8
# 1    1588  finished             H2O  struc_100_0d8500000000000001
# 2    1589  finished             H2O  struc_100_0d9000000000000001
# 3    1590  finished             H2O  struc_100_0d9500000000000002
# 4    1591  finished             H2O  struc_100_1d0000000000000002
# ..    ...       ...             ...                           ...
# 237  1908  finished             H2O    struc_OH_1d600000000000001
# 238  1909  finished             H2O    struc_OH_1d620000000000001
# 239  1910  finished             H2O    struc_OH_1d640000000000001
# 240  1911  finished             H2O    struc_OH_1d660000000000001
# 241  1912  finished             H2O    struc_OH_1d680000000000001
#
#                             subjob projectpath  \
# 0                   /struc_100_0d8        None
# 1    /struc_100_0d8500000000000001        None
# 2    /struc_100_0d9000000000000001        None
# 3    /struc_100_0d9500000000000002        None
# 4    /struc_100_1d0000000000000002        None
# ..                             ...         ...
# 237    /struc_OH_1d600000000000001        None
# 238    /struc_OH_1d620000000000001        None
# 239    /struc_OH_1d640000000000001        None
# 240    /struc_OH_1d660000000000001        None
# 241    /struc_OH_1d680000000000001        None
#
#                                                                          project  \
# 0    /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 1    /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 2    /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 3    /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 4    /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# ..                                                                           ...
# 237  /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 238  /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 239  /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 240  /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
# 241  /kyukon/data/gent/vo/000/gvo00003/vsc48948/nanoscale/vsc48948/session9/ex1/
#
#                      timestart                   timestop  totalcputime  \
# 0   2025-12-03 14:53:50.104575 2025-12-03 14:53:56.397733           6.0
# 1   2025-12-03 14:53:50.000458 2025-12-03 14:53:56.436860           6.0
# 2   2025-12-03 14:53:49.870461 2025-12-03 14:53:56.297938           6.0
# 3   2025-12-03 14:53:50.055060 2025-12-03 14:53:56.801437           6.0
# 4   2025-12-03 14:53:50.141059 2025-12-03 14:53:56.695045           6.0
# ..                         ...                        ...           ...
# 237 2025-12-03 16:08:14.051400 2025-12-03 16:08:19.917407           5.0
# 238 2025-12-03 16:08:14.015961 2025-12-03 16:08:19.791654           5.0
# 239 2025-12-03 16:08:32.010993 2025-12-03 16:08:39.222548           7.0
# 240 2025-12-03 16:08:14.357089 2025-12-03 16:08:20.687936           6.0
# 241 2025-12-03 16:08:14.087159 2025-12-03 16:08:19.834308           5.0
#
#                                computer  hamilton hamversion parentid masterid
# 0    pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 1    pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 2    pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 3    pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 4    pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# ..                                  ...       ...        ...      ...      ...
# 237  pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 238  pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 239  pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 240  pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
# 241  pyiron@node4006.donphan.os#1#doduo  Gaussian        0.1     None     None
#
# [242 rows x 15 columns]

# %% [markdown]
# ### Question 2

# %%
OH_distances = np.arange(0.6, 1.7, 0.02)
configs = []  
for dist in OH_distances:
    struc = adapt_distance(water_opt, dist)
    g16_job(ex1, name=f"struc_OH_{dist}", jobtype="sp", structure=struc, lot="MP2", basis_set = "6-31G", cluster="doduo")
# Out:
# The job struc_OH_0d6 was saved and received the ID: 1858
# Queue system id:  602558711
# The job struc_OH_0d62 was saved and received the ID: 1859
# Queue system id:  602558721
# The job struc_OH_0d64 was saved and received the ID: 1860
# Queue system id:  602558731
# The job struc_OH_0d66 was saved and received the ID: 1861
# Queue system id:  602558741
# The job struc_OH_0d68 was saved and received the ID: 1862
# Queue system id:  602558751
# The job struc_OH_0d7000000000000001 was saved and received the ID: 1863
# Queue system id:  602558761
# The job struc_OH_0d7200000000000001 was saved and received the ID: 1864
# Queue system id:  602558771
# The job struc_OH_0d7400000000000001 was saved and received the ID: 1865
# Queue system id:  602558781
# The job struc_OH_0d7600000000000001 was saved and received the ID: 1866
# Queue system id:  602558791
# The job struc_OH_0d7800000000000001 was saved and received the ID: 1867
# Queue system id:  602558801
# The job struc_OH_0d8000000000000002 was saved and received the ID: 1868
# Queue system id:  602558811
# The job struc_OH_0d8200000000000002 was saved and received the ID: 1869
# Queue system id:  602558821
# The job struc_OH_0d8400000000000002 was saved and received the ID: 1870
# Queue system id:  602558831
# The job struc_OH_0d8600000000000002 was saved and received the ID: 1871
# Queue system id:  602558841
# The job struc_OH_0d8800000000000002 was saved and received the ID: 1872
# Queue system id:  602558851
# The job struc_OH_0d9000000000000002 was saved and received the ID: 1873
# Queue system id:  602558861
# The job struc_OH_0d9200000000000003 was saved and received the ID: 1874
# Queue system id:  602558871
# The job struc_OH_0d9400000000000003 was saved and received the ID: 1875
# Queue system id:  602558881
# The job struc_OH_0d9600000000000003 was saved and received the ID: 1876
# Queue system id:  602558891
# The job struc_OH_0d9800000000000003 was saved and received the ID: 1877
# Queue system id:  602558901
# The job struc_OH_1d0000000000000004 was saved and received the ID: 1878
# Queue system id:  602558911
# The job struc_OH_1d0200000000000005 was saved and received the ID: 1879
# Queue system id:  602558921
# The job struc_OH_1d0400000000000005 was saved and received the ID: 1880
# Queue system id:  602558931
# The job struc_OH_1d0600000000000005 was saved and received the ID: 1881
# Queue system id:  602558941
# The job struc_OH_1d0800000000000005 was saved and received the ID: 1882
# Queue system id:  602558951
# The job struc_OH_1d1000000000000005 was saved and received the ID: 1883
# Queue system id:  602558961
# The job struc_OH_1d1200000000000006 was saved and received the ID: 1884
# Queue system id:  602558971
# The job struc_OH_1d1400000000000006 was saved and received the ID: 1885
# Queue system id:  602558981
# The job struc_OH_1d1600000000000006 was saved and received the ID: 1886
# Queue system id:  602558991
# The job struc_OH_1d1800000000000006 was saved and received the ID: 1887
# Queue system id:  602559001
# The job struc_OH_1d2000000000000006 was saved and received the ID: 1888
# Queue system id:  602559011
# The job struc_OH_1d2200000000000006 was saved and received the ID: 1889
# Queue system id:  602559021
# The job struc_OH_1d2400000000000007 was saved and received the ID: 1890
# Queue system id:  602559031
# The job struc_OH_1d2600000000000007 was saved and received the ID: 1891
# Queue system id:  602559041
# The job struc_OH_1d2800000000000007 was saved and received the ID: 1892
# Queue system id:  602559051
# The job struc_OH_1d3000000000000007 was saved and received the ID: 1893
# Queue system id:  602559061
# The job struc_OH_1d3200000000000007 was saved and received the ID: 1894
# Queue system id:  602559071
# The job struc_OH_1d3400000000000007 was saved and received the ID: 1895
# Queue system id:  602559081
# The job struc_OH_1d3600000000000008 was saved and received the ID: 1896
# Queue system id:  602559091
# The job struc_OH_1d3800000000000008 was saved and received the ID: 1897
# Queue system id:  602559101
# The job struc_OH_1d4000000000000008 was saved and received the ID: 1898
# Queue system id:  602559111
# The job struc_OH_1d4200000000000008 was saved and received the ID: 1899
# Queue system id:  602559121
# The job struc_OH_1d4400000000000008 was saved and received the ID: 1900
# Queue system id:  602559131
# The job struc_OH_1d4600000000000009 was saved and received the ID: 1901
# Queue system id:  602559141
# The job struc_OH_1d4800000000000009 was saved and received the ID: 1902
# Queue system id:  602559151
# The job struc_OH_1d5000000000000009 was saved and received the ID: 1903
# Queue system id:  602559161
# The job struc_OH_1d520000000000001 was saved and received the ID: 1904
# Queue system id:  602559171
# The job struc_OH_1d540000000000001 was saved and received the ID: 1905
# Queue system id:  602559181
# The job struc_OH_1d560000000000001 was saved and received the ID: 1906
# Queue system id:  602559191
# The job struc_OH_1d580000000000001 was saved and received the ID: 1907
# Queue system id:  602559201
# The job struc_OH_1d600000000000001 was saved and received the ID: 1908
# Queue system id:  602559211
# The job struc_OH_1d620000000000001 was saved and received the ID: 1909
# Queue system id:  602559221
# The job struc_OH_1d640000000000001 was saved and received the ID: 1910
# Queue system id:  602559231
# The job struc_OH_1d660000000000001 was saved and received the ID: 1911
# Queue system id:  602559241
# The job struc_OH_1d680000000000001 was saved and received the ID: 1912
# Queue system id:  602559251

# %%
# add code here to evaluate structures
configs_OH = []  
energies_OH = []
for dist in OH_distances:
    job = ex1.load(f"struc_OH_{dist}")
    structure = job.structure
    energy = job.output.energy_tot[-1] 
    
    atoms = pyiron_to_ase(structure)
    atoms.info['energy'] = energy  
    
    configs_OH.append(atoms) 
write('session9/path_OH.xyz', configs_OH)
# Out:
# HBox(children=(NGLWidget(max_frame=54), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'),…

# %%
configs_OH = read('session9/path_OH.xyz', index=':')
view(configs_OH, viewer="ngl")
# Out:
# HBox(children=(NGLWidget(max_frame=54), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'O'),…

# %% [markdown]
# # Exercise 2a: Model without explicit symmetries.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>In short:</b> <br>
#     1. Construct a neural network without explicit physical symmetries  <br>
#     2. Evaluate the accuracy of the network
# </div>

# %% [markdown]
# Now that we have our labeled training set, we can start building our first neural network potential! As an initial attempt, let us create a model which takes in atomic positions and and returns (relative) energy. To do this, we will use the Keras API which has a plethora of helper functions built around the three main deep learning frameworks in Python: PyTorch, TensorFlow and JAX. Keras will allow us to efficiently create and train neural networks without having to fully understand the underlying code of these backends. As this is not a deep learning course, most of the code implementation will be provided for you. However, feel free to enter the rabbit hole of [Keras](https://keras.io/) and [TensorFlow](https://www.tensorflow.org/) to quench your unavoidable curiosity!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Answer the following questions using the code below:</b> <br>
# <ol type='1'>
# <li> Load in your training set and select 10 structures to be used for the validation set. How can overfitting be detected by tracking the validation loss?</li>
# <br>
# <li> Construct the layout of the model and train the weights on your training set, once with the absolute energies and once with relative energies (so subtracting the average energy for example). Which approach leads to the most efficient/stable training and can you think of why this is?</li>
# <br>
# <li> Continue with the best approach from the previous question. Compute the root mean square error on the training, validation and test set. For these data sets, make a parity plot and plot the reference and predicted energies together as a function of a relevant internal coordinate. Do you see a big difference in the model accuracy on structures inside as opposed to outside of the training set?</li>
# <br>
# <li> Do you get the same energy after translating or rotating the water molecule? If not, why is this?</li>
# </ol>
# </div>

# %% [markdown]
# ### Question 1

# %% [markdown]
# Let's start by loading in the training set and selecting randomly 20% of the structures for the validation set. The model is not trained on the validation set, such that it can be used to gauge the ability of the model to generalise to unseen structures.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Visualising data</b>
#
# Data sets of molecular structures can be visualised as a function of its state, which can be characterized by some of its internal coordinates. In our case, it is obvious that we can plot the energy as a function of the bond distances and angles. For example, for O-H1 distance we might write:
#
# ```python
# distances = []
# energies = []
# for config in data_set:
#     distance = config.get_distance(0, 1)
#     energy = config.get_potential_energy()
#     distances.append(distance)
#     energies.append(energy)
#
# plt.plot(distances, energies, 'o'))
# ```
#
# </div>

# %%
configs_train = read('session9/path.xyz', index=':')
configs_valid = read('session9/path_OH.xyz', index=':')

# %%
data_set = configs_train
valid_set = configs_valid
distances = []
energies_d1 = []
for config in data_set:
    distance = config.get_distance(0, 1)
    energy = config.get_potential_energy()
    distances.append(distance)
    energies_d1.append(energy)
plt.plot(distances, energies_d1, 'o')
plt.xlabel("O-H1 distance [Å]")
plt.ylabel("Potential Energy [eV]")
plt.show()

distances = []
energies_d2 = []
for config in data_set:
    distance = config.get_distance(0, 2)
    energy = config.get_potential_energy()
    distances.append(distance)
    energies_d2.append(energy)
plt.plot(distances, energies_d2, 'o')
plt.xlabel("O-H2 distance [Å]")
plt.ylabel("Potential Energy [eV]")
plt.show()

angles = []
energies_ang = []
for config in data_set:
    angle = config.get_angle(1, 0, 2)
    energy = config.get_potential_energy()
    angles.append(angle)
    energies_ang.append(energy)
plt.plot(angles, energies_ang, 'o')
plt.xlabel("H1-O-H2 angle [degrees]")
plt.ylabel("Potential Energy [eV]")
plt.show()

# %% [markdown]
# To get a sense of the phase space coverage, it can be helpful to visualize your training sets by plotting histograms or the energy as a function of some internal coordinates. Where are your validation structures in these visualizations?

# %% [markdown]
# ### Question 2

# %% [markdown]
# Transform these `ase.Atoms`-objects into training input (here: just atomic positions) as a array/tensor with shape $(B, N, 3)$, where $B (=50)$ is the amount of structures in the training set, N is the amount of atoms in each structure ($=3$) and $3$ represents the three spatial coordinates. Also extract the output labels (energies) as a tensor with shape (B, ), i.e. one energy per training structure.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Input tensors </b>
#
# To transform our raw input into tensors that the model can use, we can use `numpy` to get the dimensions right. For example, if we have ten structure each with three atoms, the input array should have shape (10, 3, 3) and the output array shape (10, 1):
#
# ```python
# x = np.zeros((10, 3, 3))
# y = np.zeros((10, 1))
# for i, structure in data_set:
#     x[i, :, :] = structure.get_positions()
#     y[i] = structure.get_potential_energy()
# ```
#
# Afterwards, TensorFlow prefers that you convert these `numpy`-arrays into `tf.Tensor`-objects:
#
# ```python
# x = tf.constant(x)  # convert numpy-array into tf.Tensor
# y = tf.constant(y)
# ```
# </div>

# %%
B = 50 # Size of training set
N = 3 # number of atoms in each structure
x_train = np.ones((B,N,3))   #(B, N, 3)
y_train = np.ones((B,1))   # (B, 1)
x_valid = np.ones((B,N,3))
y_valid = np.ones((B,1))

for i, structure in enumerate(data_set):
    x_train[i, :, :] = structure.get_positions()
    y_train[i] = structure.get_potential_energy()

for i, structure in enumerate(valid_set):
    x_valid[i, :, :] = structure.get_positions()
    y_valid[i] = structure.get_potential_energy()

# %% [markdown]
# Let us now create a sequential neural network using the Keras functionalities, consisting of four layers: an input layer with $9$ nodes corresponding to the spatial coordinates, two dense hidden layers with $10$ nodes and an output layer with a single node to read out the energy. Figure 2 shows schematically how such a network looks; the spatial coordinates of the atoms are flattened into a vector of length $9$ and are passed through the model, which returns the predicted energy as output. Each string connecting the layers represents a single weight.

# %% [markdown]
# <figure>
# <center><img src="https://www.dropbox.com/scl/fi/oa1uc8lqxmqsoy036lzwo/neural_network1.png?rlkey=qn406uz8o2oitbiis2lovgs3e&st=01myle8k&raw=1" width="1000"></center>
# <center><figcaption>Figure 2: Schematic view of the neural network constructed in this exercise.</figcaption></center>
# </figure>

# %%
input_shape = (3, 3)    # (N, 3) where N=3 for H2O
hidden_initializer = keras.initializers.HeNormal(seed=0)    # initialization of the weights in the hidden layers, fixed seed for reproducibility
output_initializer = keras.initializers.RandomUniform(seed=0, minval=-1e-3, maxval=1e-3)    # initialization of the weights in the output layer, fixed seed for reproducibility
model_absolute = keras.Sequential()     # initialize model of sequential layers
norm_layer = keras.layers.Normalization(axis=-1)    # normalization layer to center inputs around zero
norm_layer.adapt(x_train)
model_absolute.add(keras.Input(shape=input_shape))  # input layer
model_absolute.add(norm_layer)
model_absolute.add(keras.layers.Flatten())   # flatten input into one-dimensional tensor of length 9
model_absolute.add(keras.layers.Dense(10, activation='swish', kernel_initializer=hidden_initializer))
model_absolute.add(keras.layers.Dense(10, activation='swish', kernel_initializer=hidden_initializer))
model_absolute.add(keras.layers.Dense(1, activation='linear', kernel_initializer=output_initializer))
print(model_absolute.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization) │ (None, 3, 3)           │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 230 (1.80 KB)
#  Trainable params: 221 (1.73 KB)
#  Non-trainable params: 9 (72.00 B)
# None

# %% [markdown]
# For further convencience, create a function which takes in the training points, the input shape and network layout and creates a model, similar to the function you created for submitting Gaussian jobs.

# %%
def create_nn(x_train, input_shape=(3, 3), neurons_list = [10, 10]):
    
    hidden_initializer = keras.initializers.HeNormal(seed=0)
    output_initializer = keras.initializers.RandomUniform(seed=0, minval=-1e-3, maxval=1e-3)

    model = keras.Sequential()
    
    # Normalization layer =>  centers inputs around zero, adapted to training data.
    norm_layer = keras.layers.Normalization(axis=-1)
    norm_layer.adapt(x_train)
    
    model.add(keras.Input(shape=input_shape))
    model.add(norm_layer)
    
    # Flatten layer => (N, 3) input to a 1D vector (N*3)
    model.add(keras.layers.Flatten())
    
    # Hidden dense layers
    for neurons in neurons_list:
        model.add(keras.layers.Dense(neurons, activation='swish', kernel_initializer=hidden_initializer))
        
    # Output layer =>  single node for energy prediction
    model.add(keras.layers.Dense(1, activation='linear', kernel_initializer=output_initializer))
    
    return model

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Network size</b>
#
# The size of a neural network is usually reported as the number of (un)trainable parameters, this determines the computational cost of a single forward pass. As we are working on a very simple system here, models with under 300 parameters are already very accurate. As a reference, modern day universal MLPs can have around 30 million parameters ([link](https://matbench-discovery.materialsproject.org/)), while big LLMs already have over 1 trillion parameters ([link](https://www.labellerr.com/blog/comparing-language-models-through-parameters-vs-real-life-experiments/))!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Units</b>
#
# Keep in mind that the model has no understanding of units and it will learn the PES in the units which are used in the training set, therefore makes sure to be consistent. If you're training set uses Angstrom you must always supply coordinates in Angstrom. Same thing for the output; if the energy in the training set was in eV, the model will always output in this unit. Therefore, keep track of any offsets or normalizations you apply!
# </div>

# %% [markdown]
# Now that we have constructed the layout of our neural network, we can start training. The parameters are optimized by minimizing a so-called loss function, in this case this is the mean squared error between the reference and predicted energies. In principle, you should continue training until the (validation) loss has converged, but this might take quite long depending on the model and training set. To check training efficiency, it can sometimes be helpful to train for a fixed amount of epochs.
#
# **NOTE:** re-executing the cell below will **continue** training, not **restart** it. If you wish to reset the model, you should redefine the model layout (above cell).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Learning rate</b>
#
# The learning rate determines how strongly the parameters are changed each epoch (training step). In the early stages of training this should be high, so that the model quickly learns the overall trends of the dataset. If you want to train as optimally as possible, you should decrease the learning rate each time the (validation) loss converges.
# </div>

# %%
from time import time
model_absolute.compile(
    loss=keras.losses.MeanSquaredError(reduction="sum_over_batch_size", name="mse"),
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
)
epochs = 2000
t0 = time()
model_absolute.fit(x_train, y_train, batch_size=5, epochs=epochs, validation_data=(x_valid, y_valid))
t1 = time()
print(f"Training time (s) for {epochs}:", t1 - t0)
# Out:
# Epoch 1/2000
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 8s 942ms/step - loss: 4280568.7437
# 2025-12-08 17:23:57.221457: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.221681: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.223795: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.254028: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.254273: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.254550: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.419563: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.419769: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.420003: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4282019.2609 - val_loss: 4278016.5968
# Epoch 2/2000
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 4276625.9585
# 2025-12-08 17:23:57.427099: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.427308: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:23:57.427558: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4275243.7272 - val_loss: 4265963.7214
# Epoch 3/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4257148.8915 - val_loss: 4236219.5063
# Epoch 4/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4216690.3481 - val_loss: 4175490.6859
# Epoch 5/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4139327.0225 - val_loss: 4066354.3506
# Epoch 6/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4007404.4525 - val_loss: 3889543.3307
# Epoch 7/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3802799.0609 - val_loss: 3627431.3201
# Epoch 8/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3510271.4745 - val_loss: 3267618.7402
# Epoch 9/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3121394.7426 - val_loss: 2808196.1731
# Epoch 10/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2639887.1348 - val_loss: 2264178.7482
# Epoch 11/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2087105.3395 - val_loss: 1672455.8433
# Epoch 12/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1505631.4685 - val_loss: 1092921.0346
# Epoch 13/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 957471.2043 - val_loss: 600233.0029
# Epoch 14/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 511758.6593 - val_loss: 260739.0342
# Epoch 15/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 218626.9520 - val_loss: 96617.0039
# Epoch 16/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 78763.8504 - val_loss: 63053.7910
# Epoch 17/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 39464.1507 - val_loss: 78252.5147
# Epoch 18/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36232.1067 - val_loss: 87385.8329
# Epoch 19/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 35800.0349 - val_loss: 83334.5378
# Epoch 20/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 34147.7598 - val_loss: 77265.1806
# Epoch 21/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 33261.5059 - val_loss: 73984.0390
# Epoch 22/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32816.6758 - val_loss: 72989.8920
# Epoch 23/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 32387.3664 - val_loss: 72972.3967
# Epoch 24/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31996.5695 - val_loss: 72892.8522
# Epoch 25/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31659.8562 - val_loss: 72452.4675
# Epoch 26/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31360.7800 - val_loss: 71842.9816
# Epoch 27/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31091.9928 - val_loss: 71259.0599
# Epoch 28/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30846.4232 - val_loss: 70749.6179
# Epoch 29/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30618.2784 - val_loss: 70281.4064
# Epoch 30/2000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30404.2636 - val_loss: 69817.3395
# Epoch 31/2000
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 12830.0006
# KeyboardInterrupt

# %% [markdown]
# As before, create a function to train a model.

# %%
def train_model(model, x_train, y_train, x_valid, y_valid, learning_rate=1e-3, epochs=2000):
    model.compile(
        loss=keras.losses.MeanSquaredError(reduction="sum_over_batch_size", name="mse"),
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
    )
    
    t0 = time()
    model.fit(
        x_train, 
        y_train, 
        batch_size=5,
        epochs=epochs, 
        validation_data=(x_valid, y_valid),
        verbose=1 
    )
    t1 = time()
    print(f"Training time (s) for {epochs} epochs:", t1 - t0)
    
    return model

# %% [markdown]
# The loss is very high! Construct the output tensors once more but with the average energy substracted.

# %%
B_train = len(configs_train)
B_valid = len(configs_valid)
N = 3 # number of atoms in each structure

x_train = np.ones((B_train, N, 3))   # (B, N, 3)
y_train_absolute = np.ones((B_train, 1))   # (B, 1)

x_valid = np.ones((B_valid, N, 3))
y_valid_absolute = np.ones((B_valid, 1))

for i, structure in enumerate(configs_train):
    x_train[i, :, :] = structure.get_positions()
    y_train_absolute[i] = structure.get_potential_energy()

for i, structure in enumerate(configs_valid):
    x_valid[i, :, :] = structure.get_positions()
    y_valid_absolute[i] = structure.get_potential_energy()

# Modify energies => relative to average energy
average_energy = np.mean(y_train_absolute)

y_train = y_train_absolute - average_energy
y_valid = y_valid_absolute - average_energy

# %% [markdown]
# Create a new model and train again.

# %%
model_relative = create_nn(x_train)
print(model_relative.summary())

# %%
model = train_model(model_relative, x_train, y_train, x_valid, y_valid) # The units are in MSE: so you should take the squareroot to have the values in eV

# %% [markdown]
# **CONGRATULATIONS**, you have just built and trained your very own neural nework potential, we are very proud of you! Now save it, before it disappears forever...

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Saving and loading models</b> <br>
#
# After training the model is stored in the temporary memory of the notebook as a Python object, thus if anything happens to the Python kernel, the model will be lost and will need to be retrained. Therefore, it might be wise to save your models, this can also be helpful when directly comparing different models.
#
# ```python
# model_path = "path/to/model.keras"
# model.save(model_path)
# ```
# Make sure the add the .keras extension to the path.
# Models can then be loaded like:
#
# ```python
# from tensorflow.keras.saving import load_model
# model = load_model(model_path)
# ```
# </div>

# %%
# add code to save the model
model_path = "session9/mlp_relative_energy.keras"
model_relative.save(model_path)

# %%
from tensorflow.keras.saving import load_model
model_path = "session9/mlp_relative_energy.keras"
model_relative = load_model(model_path)

# %% [markdown]
# ### Question 3

# %% [markdown]
# To get a first sense of the accuracy of the model, we can evaluate the training set and create a parity plot. A parity plot visualizes the error by plotting the points at $(E_{dft}, E_{mlp})$, a theoretical perfect model would have each point on the diagonal such that $E_{dft} = E_{mlp}$. It could also be helpful to plot the reference and predicted energies as a function of their index or some relevant internal coordinates. Are specific energies predicted much more poorly than the rest and what structures do they correspond with? Is this a surprise?

# %% [markdown]
# **HINT:** create a function that can evaluate the error of a model on a dataset and visualise the reference and predicted energies.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Error metrics</b>
#
# The accuracy of an MLP is conventionally reported as the root mean squared error between the reference and predicted energies:
#
# $ E_\text{rmse} = \sqrt{\frac{1}{B}\sum_{i = 1}^B (E_\text{ref, i} - E_\text{mlp, i})^2} $, where B is the amount of structures in the evaluated dataset.
#
# It would only make sense to compare the $E_\text{rmse}$ for systems with equal size, therefore it is usually normalized to the amount of atoms. If the number of atoms is fixed in the evaluated dataset:
#
# $ E_\text{rmse, norm} =\frac{1}{N} E_\text{rmse} $ in meV/atom, where N is the amount of atoms in the structures.
#
# Present day (non-universal) MLPs are considered 'very accurate' when their RMSE is below 1 meV/atom.
#
# </div>

# %% [markdown]
# **HINT:** to evaluate a dataset using your model, transform the input into a tensor as you did with the training set and call the `model.predict()`-function.
#
# ```python
# predicted_energies = model.predict(x_test) + reference_energy
# ```

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Shape matters</b>
#
# Input and intermediate values are internally represented using tensors which can often have complex, high-dimensional shapes. Keras will always expect the first index of the input tensor to be a batch index, which corresponds to the index of the specific sample (here molecular structure) in the total data set. So, if we want to evaluate $B$ structures and each structure has $N$ atoms with $3$ spatial coordinates, the model will expect the input tensor to have shape $(B, N, 3)$. The expected output will be a tensor of shape $(B, 1)$, which is not the same as a one-dimensional tensor of length $B$!
#
# **NOTE:** this means that if you want to evaluate a single structure, the tensor should have a batch length of 1, i.e. $(1, N, 3)$ instead of $(N, 3)$.
#
# </div>

# %%
# add code here to see how well the reference and predicted energies match
def evaluate_model(model, x_data, y_data_absolute, average_energy, name="Dataset"):
    # prediction of relative energy
    y_pred_relative = model.predict(x_data, verbose=0)
    
    # prediction back to absolute energy
    y_pred_absolute = y_pred_relative + average_energy
    
    # calculate RMSE 
    N = x_data.shape[1]
    mse = np.mean((y_data_absolute - y_pred_absolute)**2)
    rmse_eV = np.sqrt(mse)
    rmse_meV_per_atom = (rmse_eV / N) * 1000
    
    print(f"--- {name} Results ---")
    print(f"RMSE (eV): {rmse_eV:.6f}")
    print(f"Normalized RMSE (meV/atom): {rmse_meV_per_atom:.3f}")
    
    return y_data_absolute.flatten(), y_pred_absolute.flatten(), rmse_meV_per_atom

def create_parity_plot(y_ref, y_pred, rmse_meV_per_atom, name):
    plt.figure(figsize=(6, 6))
    plt.scatter(y_ref, y_pred, color=blue, label=f'Predictions')
    
    min_e = np.min(y_ref)
    max_e = np.max(y_ref)
    plt.plot([min_e, max_e], [min_e, max_e], color=red,linestyle='--', label=r'$E_\text{DFT} = E_\text{MLP}$')
    
    plt.xlabel('Reference Energy [eV]')
    plt.ylabel('Predicted Energy [eV]')
    plt.tick_params(axis='x', which='both', top=True, direction='in')
    plt.tick_params(axis='y', which='both', right=True, direction='in')
    plt.title(f'{name}')
    plt.legend(frameon=False)
    plt.show()

y_ref_train, y_pred_train, rmse_train = evaluate_model(
    model_relative, x_train, y_train_absolute, average_energy, name="Training Set"
)
create_parity_plot(y_ref_train, y_pred_train, rmse_train, "Training Set")
# Out:
# 2025-12-08 17:26:31.810182: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.810390: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.810847: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.814821: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.815107: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.815369: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.857537: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.857732: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.858177: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.862780: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.863066: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 17:26:31.863331: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# --- Training Set Results ---
# RMSE (eV): 0.055760
# Normalized RMSE (meV/atom): 18.587

# %% [markdown]
# Now evaluate on the test set!

# %%
y_ref_valid, y_pred_valid, rmse_valid = evaluate_model(
    model_relative, x_valid, y_valid_absolute, average_energy, name="test/validation set"
)
create_parity_plot(y_ref_valid, y_pred_valid, rmse_valid, "test/validation set")
# Out:
# --- test/validation set Results ---
# RMSE (eV): 0.584772
# Normalized RMSE (meV/atom): 194.924

# %%
# THIS IS AN EXTRAPOLATION TEST
valid_distances = np.array([config.get_distance(0, 1) for config in configs_valid])

plt.figure(figsize=(8, 5))
plt.scatter(valid_distances, y_ref_valid, color=red, label='Reference DFT')
plt.scatter(valid_distances, y_pred_valid, color=blue, marker='x', label='Predicted MLP')
plt.xlabel('O-H distance [Å]')
plt.ylabel('Absolute energy [eV]')
plt.tick_params(axis='x', which='both', top=True, direction='in')
plt.tick_params(axis='y', which='both', right=True, direction='in')
plt.title('Potential energy surface')
plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ### Question 4

# %%
water_opt = pr_old.load('h2o_optimized').get_structure()
test_config_ase = pyiron_to_ase(water_opt)

x_orig = np.zeros((1, 3, 3))
x_orig[0, :, :] = test_config_ase.get_positions()
y_orig = model_relative.predict(x_orig) + average_energy
print(f"Original Energy: {y_orig.item():.6f} eV")

test_config_translated = test_config_ase.copy()
test_config_translated.translate([5.0, 0.0, 0.0]) # shift 5 angstrom in x
x_trans = np.zeros((1, 3, 3))
x_trans[0, :, :] = test_config_translated.get_positions()
y_trans = model_relative.predict(x_trans) + average_energy
print(f"Translated Energy: {y_trans.item():.6f} eV")


test_config_rotated = test_config_ase.copy()
test_config_rotated.rotate(90, 'z') # rotate 90 degrees around z
x_rot = np.zeros((1, 3, 3))
x_rot[0, :, :] = test_config_rotated.get_positions()
y_rot = model_relative.predict(x_rot) + average_energy
print(f"Rotated Energy: {y_rot.item():.6f} eV")

# compare
print(f"\nDifference (Translated - Original): {y_trans.item() - y_orig.item():.6e} eV")
print(f"Difference (Rotated - Original): {y_rot.item() - y_orig.item():.6e} eV")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Original Energy: -2071.087951 eV
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Translated Energy: 305385880.114160 eV
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Rotated Energy: 47957034.394358 eV
#
# Difference (Translated - Original): 3.053880e+08 eV
# Difference (Rotated - Original): 4.795911e+07 eV

# %% [markdown]
# # Exercise 2b: Incorporating geometric symmetries.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>In short:</b> <br>
#     1. Construct a neural network that respects rototranslational invariance  <br>
#     2. Evaluate the accuracy of the network and observe the improvements
# </div>

# %% [markdown]
# To be able to pass a molecular structure through the neural network, we need to transform that structure into a numerical input tensor/vector, called a descriptor. This process of transforming the atomic coordinates (and corresponding species) into rich descriptive feature vectors is called embedding and is an entire research topic in itself. A good embedding should uniquely, richly and efficiently decribe the system (or the chemical environment of an atom) and respect the fundamental symmetries. Sophisticated MLP architectures can have very complex embedding schemes, for example MACE uses message passing neural networks to learn the embedding. The most basic and intuitive descriptor was handled in the previous exercise, where we simply use the spatial coordinates of each atom as input. As you saw, this does not give a transferable model, because we basically incorporate no physical symmetries into the descriptor of the system. We can quite easily improve on this by using descriptors which have rototranslational symmetry. There are several different possibilities, can you think of a descriptor for the molecular structure which respects the global rotation and rotation invariance? Remember that the number of independent degrees of freedom is $3N-6$ ($=3$), therefore you should be able to completely describe the state of the water molecule using $3$ parameters.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Answer the following questions using the code below:</b> <br>
# <ol type='1'>
# <li> Can you think of a descriptor for a water molecule that respects the rototranslational symmetry? Adapt the input and the network layout to handle this, remember that the shape of the input will differ.</li>
# <br>
# <li> Train a model using this decriptor. What happens to the training efficieny, accuracy and transferability?</li>
# <br>
# <li> Are we missing any additional fundamental symmetries? What happens when you swap the two hydrogen atoms? Do you notice any other flaws with this model and the previous one?</li>
# </ol>
# </div>

# %% [markdown]
# ### Question 1

# %% [markdown]
# **HINT:** If you use a descriptor with three parameters, the input shape of the model will change from $(3, 3)$ to $(3, )$.

# %%
# add code here to convert the descriptor of each structure into a tf.Tensors

B_train = len(configs_train)
B_valid = len(configs_valid)

x_train_inv = np.zeros((B_train, 3)) 
x_valid_inv = np.zeros((B_valid, 3))

for i, config in enumerate(configs_train):
    r_oh1 = config.get_distance(0, 1)  # O=0, H1=1, H2=2
    r_oh2 = config.get_distance(0, 2)
    angle = config.get_angle(1, 0, 2)
    x_train_inv[i, 0] = r_oh1
    x_train_inv[i, 1] = r_oh2
    x_train_inv[i, 2] = angle


for i, config in enumerate(configs_valid):
    r_oh1 = config.get_distance(0, 1)
    r_oh2 = config.get_distance(0, 2)
    angle = config.get_angle(1, 0, 2)
    x_valid_inv[i, 0] = r_oh1
    x_valid_inv[i, 1] = r_oh2
    x_valid_inv[i, 2] = angle

x_train_inv = tf.constant(x_train_inv, dtype=tf.float64)
x_valid_inv = tf.constant(x_valid_inv, dtype=tf.float64)
y_train_tf = tf.constant(y_train, dtype=tf.float64)
y_valid_tf = tf.constant(y_valid, dtype=tf.float64)

# %% [markdown]
# ### Question 2

# %%
input_shape_inv = (3,)
neurons_list = [10, 10]

model_invariant = create_nn(x_train_inv, input_shape=input_shape_inv, neurons_list=neurons_list)

print(model_invariant.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 3)              │             7 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 168 (1.31 KB)
#  Trainable params: 161 (1.26 KB)
#  Non-trainable params: 7 (56.00 B)
# None

# %%
epochs = 1000 # Increasing epochs to ensure convergence
model_invariant = train_model(
    model_invariant, 
    x_train_inv, 
    y_train_tf, 
    x_valid_inv, 
    y_valid_tf, 
    learning_rate=1e-3, 
    epochs=epochs
)
# Out:
# Epoch 1/1000
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 6s 728ms/step - loss: 1.8740
# 2025-12-08 18:05:40.623392: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.623619: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.625747: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.655534: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.655779: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.656048: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.817728: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.817923: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.818157: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5386 - val_loss: 4.3631
# Epoch 2/1000
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.8284
# 2025-12-08 18:05:40.825028: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.825240: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 2025-12-08 18:05:40.825495: W tensorflow/core/util/util.cc:163] Not handling type DT_DOUBLE
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5165 - val_loss: 4.3378
# Epoch 3/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4974 - val_loss: 4.3122
# Epoch 4/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4775 - val_loss: 4.2851
# Epoch 5/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4563 - val_loss: 4.2562
# Epoch 6/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4338 - val_loss: 4.2252
# Epoch 7/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4100 - val_loss: 4.1921
# Epoch 8/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3851 - val_loss: 4.1568
# Epoch 9/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3592 - val_loss: 4.1193
# Epoch 10/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3325 - val_loss: 4.0796
# Epoch 11/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3053 - val_loss: 4.0380
# Epoch 12/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2778 - val_loss: 3.9945
# Epoch 13/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2500 - val_loss: 3.9492
# Epoch 14/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2221 - val_loss: 3.9024
# Epoch 15/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1944 - val_loss: 3.8543
# Epoch 16/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1667 - val_loss: 3.8051
# Epoch 17/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1392 - val_loss: 3.7549
# Epoch 18/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1119 - val_loss: 3.7040
# Epoch 19/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0848 - val_loss: 3.6524
# Epoch 20/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0579 - val_loss: 3.6003
# Epoch 21/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0313 - val_loss: 3.5480
# Epoch 22/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0048 - val_loss: 3.4955
# Epoch 23/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9787 - val_loss: 3.4430
# Epoch 24/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9528 - val_loss: 3.3908
# Epoch 25/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9272 - val_loss: 3.3391
# Epoch 26/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9020 - val_loss: 3.2879
# Epoch 27/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8773 - val_loss: 3.2377
# Epoch 28/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8531 - val_loss: 3.1887
# Epoch 29/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8295 - val_loss: 3.1411
# Epoch 30/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8066 - val_loss: 3.0951
# Epoch 31/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7845 - val_loss: 3.0508
# Epoch 32/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7631 - val_loss: 3.0084
# Epoch 33/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7425 - val_loss: 2.9679
# Epoch 34/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7227 - val_loss: 2.9292
# Epoch 35/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7036 - val_loss: 2.8923
# Epoch 36/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6852 - val_loss: 2.8570
# Epoch 37/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6674 - val_loss: 2.8233
# Epoch 38/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6502 - val_loss: 2.7909
# Epoch 39/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6335 - val_loss: 2.7597
# Epoch 40/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6173 - val_loss: 2.7295
# Epoch 41/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6015 - val_loss: 2.7003
# Epoch 42/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5860 - val_loss: 2.6719
# Epoch 43/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5709 - val_loss: 2.6442
# Epoch 44/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5561 - val_loss: 2.6170
# Epoch 45/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5416 - val_loss: 2.5904
# Epoch 46/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5274 - val_loss: 2.5641
# Epoch 47/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5134 - val_loss: 2.5382
# Epoch 48/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4996 - val_loss: 2.5126
# Epoch 49/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4861 - val_loss: 2.4872
# Epoch 50/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4728 - val_loss: 2.4620
# Epoch 51/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4598 - val_loss: 2.4370
# Epoch 52/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4470 - val_loss: 2.4120
# Epoch 53/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4344 - val_loss: 2.3871
# Epoch 54/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4221 - val_loss: 2.3623
# Epoch 55/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4101 - val_loss: 2.3375
# Epoch 56/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3983 - val_loss: 2.3127
# Epoch 57/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3868 - val_loss: 2.2878
# Epoch 58/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3756 - val_loss: 2.2629
# Epoch 59/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3647 - val_loss: 2.2379
# Epoch 60/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3540 - val_loss: 2.2127
# Epoch 61/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3436 - val_loss: 2.1875
# Epoch 62/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3335 - val_loss: 2.1621
# Epoch 63/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3237 - val_loss: 2.1365
# Epoch 64/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3142 - val_loss: 2.1108
# Epoch 65/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3050 - val_loss: 2.0849
# Epoch 66/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2960 - val_loss: 2.0588
# Epoch 67/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2874 - val_loss: 2.0325
# Epoch 68/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2790 - val_loss: 2.0061
# Epoch 69/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2709 - val_loss: 1.9794
# Epoch 70/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2631 - val_loss: 1.9526
# Epoch 71/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2555 - val_loss: 1.9257
# Epoch 72/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2483 - val_loss: 1.8987
# Epoch 73/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2412 - val_loss: 1.8715
# Epoch 74/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2345 - val_loss: 1.8443
# Epoch 75/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2279 - val_loss: 1.8171
# Epoch 76/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2216 - val_loss: 1.7898
# Epoch 77/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2156 - val_loss: 1.7626
# Epoch 78/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2097 - val_loss: 1.7355
# Epoch 79/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2041 - val_loss: 1.7086
# Epoch 80/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1986 - val_loss: 1.6818
# Epoch 81/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1934 - val_loss: 1.6553
# Epoch 82/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1884 - val_loss: 1.6291
# Epoch 83/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1835 - val_loss: 1.6032
# Epoch 84/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1788 - val_loss: 1.5777
# Epoch 85/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1742 - val_loss: 1.5527
# Epoch 86/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1699 - val_loss: 1.5282
# Epoch 87/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1656 - val_loss: 1.5042
# Epoch 88/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1616 - val_loss: 1.4809
# Epoch 89/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1576 - val_loss: 1.4581
# Epoch 90/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1538 - val_loss: 1.4360
# Epoch 91/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1502 - val_loss: 1.4146
# Epoch 92/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1466 - val_loss: 1.3939
# Epoch 93/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1432 - val_loss: 1.3740
# Epoch 94/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1399 - val_loss: 1.3547
# Epoch 95/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1367 - val_loss: 1.3362
# Epoch 96/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1337 - val_loss: 1.3184
# Epoch 97/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1307 - val_loss: 1.3013
# Epoch 98/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1278 - val_loss: 1.2849
# Epoch 99/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1251 - val_loss: 1.2692
# Epoch 100/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1224 - val_loss: 1.2541
# Epoch 101/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1199 - val_loss: 1.2397
# Epoch 102/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1174 - val_loss: 1.2260
# Epoch 103/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1150 - val_loss: 1.2128
# Epoch 104/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1127 - val_loss: 1.2002
# Epoch 105/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1105 - val_loss: 1.1882
# Epoch 106/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1084 - val_loss: 1.1767
# Epoch 107/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1063 - val_loss: 1.1657
# Epoch 108/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1043 - val_loss: 1.1552
# Epoch 109/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1024 - val_loss: 1.1452
# Epoch 110/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1005 - val_loss: 1.1356
# Epoch 111/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0987 - val_loss: 1.1265
# Epoch 112/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0970 - val_loss: 1.1178
# Epoch 113/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0953 - val_loss: 1.1094
# Epoch 114/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0937 - val_loss: 1.1014
# Epoch 115/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0921 - val_loss: 1.0938
# Epoch 116/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0905 - val_loss: 1.0865
# Epoch 117/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0891 - val_loss: 1.0795
# Epoch 118/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0876 - val_loss: 1.0728
# Epoch 119/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0862 - val_loss: 1.0664
# Epoch 120/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0849 - val_loss: 1.0603
# Epoch 121/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0836 - val_loss: 1.0545
# Epoch 122/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0823 - val_loss: 1.0489
# Epoch 123/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0811 - val_loss: 1.0435
# Epoch 124/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0799 - val_loss: 1.0383
# Epoch 125/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0788 - val_loss: 1.0334
# Epoch 126/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0776 - val_loss: 1.0286
# Epoch 127/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0765 - val_loss: 1.0241
# Epoch 128/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0755 - val_loss: 1.0197
# Epoch 129/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0744 - val_loss: 1.0155
# Epoch 130/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0734 - val_loss: 1.0114
# Epoch 131/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0725 - val_loss: 1.0075
# Epoch 132/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0715 - val_loss: 1.0037
# Epoch 133/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0706 - val_loss: 1.0001
# Epoch 134/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0697 - val_loss: 0.9966
# Epoch 135/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0688 - val_loss: 0.9932
# Epoch 136/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0679 - val_loss: 0.9899
# Epoch 137/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0671 - val_loss: 0.9868
# Epoch 138/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0663 - val_loss: 0.9837
# Epoch 139/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0655 - val_loss: 0.9807
# Epoch 140/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0647 - val_loss: 0.9778
# Epoch 141/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0639 - val_loss: 0.9750
# Epoch 142/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0632 - val_loss: 0.9723
# Epoch 143/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0624 - val_loss: 0.9696
# Epoch 144/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0617 - val_loss: 0.9670
# Epoch 145/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0610 - val_loss: 0.9645
# Epoch 146/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0603 - val_loss: 0.9620
# Epoch 147/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0596 - val_loss: 0.9596
# Epoch 148/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0590 - val_loss: 0.9572
# Epoch 149/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0583 - val_loss: 0.9549
# Epoch 150/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0577 - val_loss: 0.9526
# Epoch 151/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0570 - val_loss: 0.9503
# Epoch 152/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0564 - val_loss: 0.9481
# Epoch 153/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0558 - val_loss: 0.9459
# Epoch 154/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0552 - val_loss: 0.9438
# Epoch 155/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0546 - val_loss: 0.9417
# Epoch 156/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0540 - val_loss: 0.9396
# Epoch 157/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0534 - val_loss: 0.9375
# Epoch 158/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0529 - val_loss: 0.9355
# Epoch 159/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0523 - val_loss: 0.9335
# Epoch 160/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0517 - val_loss: 0.9315
# Epoch 161/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0512 - val_loss: 0.9295
# Epoch 162/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0507 - val_loss: 0.9275
# Epoch 163/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0501 - val_loss: 0.9256
# Epoch 164/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0496 - val_loss: 0.9236
# Epoch 165/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0491 - val_loss: 0.9217
# Epoch 166/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0485 - val_loss: 0.9197
# Epoch 167/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0480 - val_loss: 0.9178
# Epoch 168/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0475 - val_loss: 0.9159
# Epoch 169/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0470 - val_loss: 0.9140
# Epoch 170/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0465 - val_loss: 0.9121
# Epoch 171/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0460 - val_loss: 0.9102
# Epoch 172/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0455 - val_loss: 0.9083
# Epoch 173/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0450 - val_loss: 0.9064
# Epoch 174/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0446 - val_loss: 0.9045
# Epoch 175/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0441 - val_loss: 0.9027
# Epoch 176/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0436 - val_loss: 0.9008
# Epoch 177/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0431 - val_loss: 0.8989
# Epoch 178/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0427 - val_loss: 0.8970
# Epoch 179/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0422 - val_loss: 0.8951
# Epoch 180/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0417 - val_loss: 0.8932
# Epoch 181/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0413 - val_loss: 0.8913
# Epoch 182/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0408 - val_loss: 0.8894
# Epoch 183/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0404 - val_loss: 0.8876
# Epoch 184/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0399 - val_loss: 0.8857
# Epoch 185/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0395 - val_loss: 0.8838
# Epoch 186/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0390 - val_loss: 0.8819
# Epoch 187/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0386 - val_loss: 0.8800
# Epoch 188/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0382 - val_loss: 0.8781
# Epoch 189/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0377 - val_loss: 0.8762
# Epoch 190/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0373 - val_loss: 0.8742
# Epoch 191/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0369 - val_loss: 0.8723
# Epoch 192/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0365 - val_loss: 0.8704
# Epoch 193/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0361 - val_loss: 0.8685
# Epoch 194/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0356 - val_loss: 0.8666
# Epoch 195/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0352 - val_loss: 0.8647
# Epoch 196/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0348 - val_loss: 0.8627
# Epoch 197/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0344 - val_loss: 0.8608
# Epoch 198/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0340 - val_loss: 0.8589
# Epoch 199/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0336 - val_loss: 0.8570
# Epoch 200/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0332 - val_loss: 0.8550
# Epoch 201/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0328 - val_loss: 0.8531
# Epoch 202/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0325 - val_loss: 0.8512
# Epoch 203/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0321 - val_loss: 0.8492
# Epoch 204/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0317 - val_loss: 0.8473
# Epoch 205/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0313 - val_loss: 0.8453
# Epoch 206/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0309 - val_loss: 0.8434
# Epoch 207/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0306 - val_loss: 0.8414
# Epoch 208/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0302 - val_loss: 0.8395
# Epoch 209/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0298 - val_loss: 0.8376
# Epoch 210/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0295 - val_loss: 0.8356
# Epoch 211/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0291 - val_loss: 0.8337
# Epoch 212/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0288 - val_loss: 0.8317
# Epoch 213/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0284 - val_loss: 0.8298
# Epoch 214/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0281 - val_loss: 0.8278
# Epoch 215/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0277 - val_loss: 0.8259
# Epoch 216/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0274 - val_loss: 0.8240
# Epoch 217/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0271 - val_loss: 0.8220
# Epoch 218/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0267 - val_loss: 0.8201
# Epoch 219/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0264 - val_loss: 0.8181
# Epoch 220/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0261 - val_loss: 0.8162
# Epoch 221/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0258 - val_loss: 0.8143
# Epoch 222/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0254 - val_loss: 0.8123
# Epoch 223/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0251 - val_loss: 0.8104
# Epoch 224/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0248 - val_loss: 0.8085
# Epoch 225/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0245 - val_loss: 0.8066
# Epoch 226/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0242 - val_loss: 0.8047
# Epoch 227/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0239 - val_loss: 0.8028
# Epoch 228/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0236 - val_loss: 0.8009
# Epoch 229/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0233 - val_loss: 0.7990
# Epoch 230/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0230 - val_loss: 0.7971
# Epoch 231/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0227 - val_loss: 0.7952
# Epoch 232/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0225 - val_loss: 0.7933
# Epoch 233/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0222 - val_loss: 0.7914
# Epoch 234/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0219 - val_loss: 0.7895
# Epoch 235/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0216 - val_loss: 0.7877
# Epoch 236/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0213 - val_loss: 0.7858
# Epoch 237/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0211 - val_loss: 0.7839
# Epoch 238/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0208 - val_loss: 0.7821
# Epoch 239/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - val_loss: 0.7803
# Epoch 240/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0203 - val_loss: 0.7784
# Epoch 241/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0200 - val_loss: 0.7766
# Epoch 242/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0198 - val_loss: 0.7748
# Epoch 243/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0195 - val_loss: 0.7730
# Epoch 244/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0193 - val_loss: 0.7712
# Epoch 245/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - val_loss: 0.7694
# Epoch 246/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0188 - val_loss: 0.7676
# Epoch 247/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - val_loss: 0.7659
# Epoch 248/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0183 - val_loss: 0.7641
# Epoch 249/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0181 - val_loss: 0.7624
# Epoch 250/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0179 - val_loss: 0.7606
# Epoch 251/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177 - val_loss: 0.7589
# Epoch 252/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - val_loss: 0.7572
# Epoch 253/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0172 - val_loss: 0.7555
# Epoch 254/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0170 - val_loss: 0.7538
# Epoch 255/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0168 - val_loss: 0.7521
# Epoch 256/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0166 - val_loss: 0.7504
# Epoch 257/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0164 - val_loss: 0.7488
# Epoch 258/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0162 - val_loss: 0.7471
# Epoch 259/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0160 - val_loss: 0.7455
# Epoch 260/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0158 - val_loss: 0.7438
# Epoch 261/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0156 - val_loss: 0.7422
# Epoch 262/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0154 - val_loss: 0.7406
# Epoch 263/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0152 - val_loss: 0.7390
# Epoch 264/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0150 - val_loss: 0.7375
# Epoch 265/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0148 - val_loss: 0.7359
# Epoch 266/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0146 - val_loss: 0.7344
# Epoch 267/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0144 - val_loss: 0.7328
# Epoch 268/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0143 - val_loss: 0.7313
# Epoch 269/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0141 - val_loss: 0.7298
# Epoch 270/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0139 - val_loss: 0.7283
# Epoch 271/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0138 - val_loss: 0.7269
# Epoch 272/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136 - val_loss: 0.7254
# Epoch 273/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0134 - val_loss: 0.7239
# Epoch 274/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0133 - val_loss: 0.7225
# Epoch 275/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0131 - val_loss: 0.7211
# Epoch 276/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0129 - val_loss: 0.7197
# Epoch 277/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0128 - val_loss: 0.7183
# Epoch 278/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0126 - val_loss: 0.7169
# Epoch 279/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0125 - val_loss: 0.7156
# Epoch 280/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0123 - val_loss: 0.7142
# Epoch 281/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0122 - val_loss: 0.7129
# Epoch 282/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0121 - val_loss: 0.7116
# Epoch 283/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0119 - val_loss: 0.7103
# Epoch 284/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0118 - val_loss: 0.7090
# Epoch 285/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0116 - val_loss: 0.7077
# Epoch 286/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0115 - val_loss: 0.7065
# Epoch 287/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0114 - val_loss: 0.7052
# Epoch 288/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0112 - val_loss: 0.7040
# Epoch 289/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0111 - val_loss: 0.7028
# Epoch 290/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0110 - val_loss: 0.7016
# Epoch 291/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0109 - val_loss: 0.7004
# Epoch 292/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0107 - val_loss: 0.6992
# Epoch 293/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0106 - val_loss: 0.6981
# Epoch 294/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0105 - val_loss: 0.6970
# Epoch 295/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0104 - val_loss: 0.6958
# Epoch 296/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0103 - val_loss: 0.6947
# Epoch 297/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0102 - val_loss: 0.6937
# Epoch 298/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101 - val_loss: 0.6926
# Epoch 299/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0100 - val_loss: 0.6915
# Epoch 300/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0099 - val_loss: 0.6905
# Epoch 301/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0097 - val_loss: 0.6895
# Epoch 302/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0096 - val_loss: 0.6884
# Epoch 303/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0095 - val_loss: 0.6874
# Epoch 304/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0094 - val_loss: 0.6865
# Epoch 305/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0094 - val_loss: 0.6855
# Epoch 306/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0093 - val_loss: 0.6845
# Epoch 307/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0092 - val_loss: 0.6836
# Epoch 308/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0091 - val_loss: 0.6827
# Epoch 309/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0090 - val_loss: 0.6818
# Epoch 310/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0089 - val_loss: 0.6809
# Epoch 311/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0088 - val_loss: 0.6800
# Epoch 312/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0087 - val_loss: 0.6791
# Epoch 313/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086 - val_loss: 0.6783
# Epoch 314/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086 - val_loss: 0.6774
# Epoch 315/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0085 - val_loss: 0.6766
# Epoch 316/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084 - val_loss: 0.6758
# Epoch 317/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0083 - val_loss: 0.6750
# Epoch 318/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0082 - val_loss: 0.6742
# Epoch 319/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0082 - val_loss: 0.6734
# Epoch 320/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - val_loss: 0.6727
# Epoch 321/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0080 - val_loss: 0.6719
# Epoch 322/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0079 - val_loss: 0.6712
# Epoch 323/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0079 - val_loss: 0.6705
# Epoch 324/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0078 - val_loss: 0.6698
# Epoch 325/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077 - val_loss: 0.6691
# Epoch 326/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077 - val_loss: 0.6684
# Epoch 327/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076 - val_loss: 0.6678
# Epoch 328/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - val_loss: 0.6671
# Epoch 329/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - val_loss: 0.6665
# Epoch 330/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0074 - val_loss: 0.6658
# Epoch 331/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073 - val_loss: 0.6652
# Epoch 332/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073 - val_loss: 0.6646
# Epoch 333/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072 - val_loss: 0.6640
# Epoch 334/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072 - val_loss: 0.6635
# Epoch 335/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0071 - val_loss: 0.6629
# Epoch 336/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0070 - val_loss: 0.6623
# Epoch 337/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070 - val_loss: 0.6618
# Epoch 338/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - val_loss: 0.6613
# Epoch 339/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - val_loss: 0.6607
# Epoch 340/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068 - val_loss: 0.6602
# Epoch 341/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068 - val_loss: 0.6597
# Epoch 342/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - val_loss: 0.6592
# Epoch 343/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - val_loss: 0.6587
# Epoch 344/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - val_loss: 0.6583
# Epoch 345/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - val_loss: 0.6578
# Epoch 346/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - val_loss: 0.6574
# Epoch 347/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - val_loss: 0.6569
# Epoch 348/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064 - val_loss: 0.6565
# Epoch 349/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064 - val_loss: 0.6561
# Epoch 350/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0063 - val_loss: 0.6557
# Epoch 351/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0063 - val_loss: 0.6553
# Epoch 352/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - val_loss: 0.6549
# Epoch 353/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - val_loss: 0.6545
# Epoch 354/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - val_loss: 0.6541
# Epoch 355/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - val_loss: 0.6538
# Epoch 356/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - val_loss: 0.6534
# Epoch 357/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - val_loss: 0.6531
# Epoch 358/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - val_loss: 0.6527
# Epoch 359/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - val_loss: 0.6524
# Epoch 360/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059 - val_loss: 0.6521
# Epoch 361/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059 - val_loss: 0.6518
# Epoch 362/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0058 - val_loss: 0.6515
# Epoch 363/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0058 - val_loss: 0.6512
# Epoch 364/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0058 - val_loss: 0.6509
# Epoch 365/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0057 - val_loss: 0.6506
# Epoch 366/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057 - val_loss: 0.6503
# Epoch 367/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057 - val_loss: 0.6500
# Epoch 368/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0056 - val_loss: 0.6498
# Epoch 369/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0056 - val_loss: 0.6495
# Epoch 370/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0056 - val_loss: 0.6493
# Epoch 371/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0055 - val_loss: 0.6491
# Epoch 372/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055 - val_loss: 0.6488
# Epoch 373/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055 - val_loss: 0.6486
# Epoch 374/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0054 - val_loss: 0.6484
# Epoch 375/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0054 - val_loss: 0.6482
# Epoch 376/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0054 - val_loss: 0.6480
# Epoch 377/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0053 - val_loss: 0.6478
# Epoch 378/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0053 - val_loss: 0.6476
# Epoch 379/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0053 - val_loss: 0.6474
# Epoch 380/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0052 - val_loss: 0.6472
# Epoch 381/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.6471
# Epoch 382/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0052 - val_loss: 0.6469
# Epoch 383/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0052 - val_loss: 0.6467
# Epoch 384/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0051 - val_loss: 0.6466
# Epoch 385/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0051 - val_loss: 0.6464
# Epoch 386/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - val_loss: 0.6463
# Epoch 387/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050 - val_loss: 0.6462
# Epoch 388/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050 - val_loss: 0.6460
# Epoch 389/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050 - val_loss: 0.6459
# Epoch 390/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050 - val_loss: 0.6458
# Epoch 391/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049 - val_loss: 0.6457
# Epoch 392/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0049 - val_loss: 0.6455
# Epoch 393/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049 - val_loss: 0.6454
# Epoch 394/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0049 - val_loss: 0.6453
# Epoch 395/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0048 - val_loss: 0.6452
# Epoch 396/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0048 - val_loss: 0.6451
# Epoch 397/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0048 - val_loss: 0.6451
# Epoch 398/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0048 - val_loss: 0.6450
# Epoch 399/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - val_loss: 0.6449
# Epoch 400/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - val_loss: 0.6448
# Epoch 401/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0047 - val_loss: 0.6447
# Epoch 402/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0047 - val_loss: 0.6447
# Epoch 403/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.6446
# Epoch 404/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.6446
# Epoch 405/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.6445
# Epoch 406/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.6445
# Epoch 407/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0046 - val_loss: 0.6444
# Epoch 408/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045 - val_loss: 0.6444
# Epoch 409/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045 - val_loss: 0.6443
# Epoch 410/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045 - val_loss: 0.6443
# Epoch 411/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045 - val_loss: 0.6443
# Epoch 412/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 0.6442
# Epoch 413/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0044 - val_loss: 0.6442
# Epoch 414/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0044 - val_loss: 0.6442
# Epoch 415/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 0.6442
# Epoch 416/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - val_loss: 0.6442
# Epoch 417/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.6442
# Epoch 418/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.6441
# Epoch 419/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.6441
# Epoch 420/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.6441
# Epoch 421/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.6441
# Epoch 422/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042 - val_loss: 0.6441
# Epoch 423/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - val_loss: 0.6442
# Epoch 424/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - val_loss: 0.6442
# Epoch 425/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042 - val_loss: 0.6442
# Epoch 426/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042 - val_loss: 0.6442
# Epoch 427/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.6442
# Epoch 428/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.6442
# Epoch 429/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.6443
# Epoch 430/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.6443
# Epoch 431/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041 - val_loss: 0.6443
# Epoch 432/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.6444
# Epoch 433/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.6444
# Epoch 434/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.6444
# Epoch 435/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - val_loss: 0.6445
# Epoch 436/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.6445
# Epoch 437/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.6446
# Epoch 438/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0039 - val_loss: 0.6446
# Epoch 439/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - val_loss: 0.6446
# Epoch 440/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0039 - val_loss: 0.6447
# Epoch 441/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0039 - val_loss: 0.6448
# Epoch 442/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - val_loss: 0.6448
# Epoch 443/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - val_loss: 0.6449
# Epoch 444/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.6449
# Epoch 445/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.6450
# Epoch 446/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.6451
# Epoch 447/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.6451
# Epoch 448/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.6452
# Epoch 449/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.6453
# Epoch 450/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.6453
# Epoch 451/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.6454
# Epoch 452/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - val_loss: 0.6455
# Epoch 453/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.6456
# Epoch 454/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.6456
# Epoch 455/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037 - val_loss: 0.6457
# Epoch 456/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.6458
# Epoch 457/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - val_loss: 0.6459
# Epoch 458/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.6460
# Epoch 459/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.6461
# Epoch 460/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.6462
# Epoch 461/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.6463
# Epoch 462/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.6464
# Epoch 463/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - val_loss: 0.6465
# Epoch 464/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.6465
# Epoch 465/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - val_loss: 0.6466
# Epoch 466/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - val_loss: 0.6468
# Epoch 467/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.6469
# Epoch 468/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - val_loss: 0.6470
# Epoch 469/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - val_loss: 0.6471
# Epoch 470/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 0.6472
# Epoch 471/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 0.6473
# Epoch 472/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - val_loss: 0.6474
# Epoch 473/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - val_loss: 0.6475
# Epoch 474/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - val_loss: 0.6476
# Epoch 475/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - val_loss: 0.6477
# Epoch 476/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.6478
# Epoch 477/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.6480
# Epoch 478/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.6481
# Epoch 479/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.6482
# Epoch 480/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.6483
# Epoch 481/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - val_loss: 0.6484
# Epoch 482/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.6486
# Epoch 483/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033 - val_loss: 0.6487
# Epoch 484/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - val_loss: 0.6488
# Epoch 485/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - val_loss: 0.6490
# Epoch 486/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.6491
# Epoch 487/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - val_loss: 0.6492
# Epoch 488/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - val_loss: 0.6493
# Epoch 489/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - val_loss: 0.6495
# Epoch 490/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - val_loss: 0.6496
# Epoch 491/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.6497
# Epoch 492/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - val_loss: 0.6499
# Epoch 493/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.6500
# Epoch 494/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.6502
# Epoch 495/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - val_loss: 0.6503
# Epoch 496/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - val_loss: 0.6504
# Epoch 497/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.6506
# Epoch 498/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - val_loss: 0.6507
# Epoch 499/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - val_loss: 0.6509
# Epoch 500/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.6510
# Epoch 501/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.6512
# Epoch 502/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.6513
# Epoch 503/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - val_loss: 0.6515
# Epoch 504/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.6516
# Epoch 505/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.6518
# Epoch 506/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - val_loss: 0.6519
# Epoch 507/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6521
# Epoch 508/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6522
# Epoch 509/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6524
# Epoch 510/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6525
# Epoch 511/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6527
# Epoch 512/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6529
# Epoch 513/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6530
# Epoch 514/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - val_loss: 0.6532
# Epoch 515/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6533
# Epoch 516/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6535
# Epoch 517/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6537
# Epoch 518/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6538
# Epoch 519/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6540
# Epoch 520/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6542
# Epoch 521/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6543
# Epoch 522/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6545
# Epoch 523/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - val_loss: 0.6547
# Epoch 524/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - val_loss: 0.6548
# Epoch 525/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - val_loss: 0.6550
# Epoch 526/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - val_loss: 0.6552
# Epoch 527/1000
# ...
# Epoch 829/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0783e-04 - val_loss: 0.7126
# Epoch 830/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.0512e-04 - val_loss: 0.7127
# Epoch 831/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0250e-04 - val_loss: 0.7127
# Epoch 832/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9978e-04 - val_loss: 0.7129
# Epoch 833/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.9722e-04 - val_loss: 0.7129
# Epoch 834/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9446e-04 - val_loss: 0.7131
# Epoch 835/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9203e-04 - val_loss: 0.7131
# Epoch 836/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8914e-04 - val_loss: 0.7133
# Epoch 837/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8695e-04 - val_loss: 0.7132
# Epoch 838/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8378e-04 - val_loss: 0.7135
# Epoch 839/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8208e-04 - val_loss: 0.7133
# Epoch 840/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7826e-04 - val_loss: 0.7139
# Epoch 841/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7767e-04 - val_loss: 0.7132
# Epoch 842/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7240e-04 - val_loss: 0.7144
# Epoch 843/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7440e-04 - val_loss: 0.7129
# Epoch 844/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6605e-04 - val_loss: 0.7154
# Epoch 845/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7456e-04 - val_loss: 0.7119
# Epoch 846/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6043e-04 - val_loss: 0.7174
# Epoch 847/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8721e-04 - val_loss: 0.7093
# Epoch 848/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6678e-04 - val_loss: 0.7219
# Epoch 849/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.5394e-04 - val_loss: 0.7031
# Epoch 850/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.5821e-04 - val_loss: 0.7324
# Epoch 851/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.6893
# Epoch 852/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - val_loss: 0.7569
# Epoch 853/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - val_loss: 0.6638
# Epoch 854/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - val_loss: 0.8009
# Epoch 855/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - val_loss: 0.6447
# Epoch 856/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074 - val_loss: 0.8139
# Epoch 857/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - val_loss: 0.6735
# Epoch 858/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0072 - val_loss: 0.7486
# Epoch 859/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055 - val_loss: 0.7372
# Epoch 860/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0063 - val_loss: 0.6823
# Epoch 861/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0048 - val_loss: 0.7873
# Epoch 862/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064 - val_loss: 0.6632
# Epoch 863/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - val_loss: 0.7706
# Epoch 864/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - val_loss: 0.6915
# Epoch 865/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.7312
# Epoch 866/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0010 - val_loss: 0.7133
# Epoch 867/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8894e-04 - val_loss: 0.7176
# Epoch 868/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1197e-04 - val_loss: 0.7171
# Epoch 869/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8821e-04 - val_loss: 0.7163
# Epoch 870/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9661e-04 - val_loss: 0.7163
# Epoch 871/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8181e-04 - val_loss: 0.7168
# Epoch 872/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9635e-04 - val_loss: 0.7158
# Epoch 873/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7734e-04 - val_loss: 0.7170
# Epoch 874/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9131e-04 - val_loss: 0.7159
# Epoch 875/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7657e-04 - val_loss: 0.7168
# Epoch 876/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8493e-04 - val_loss: 0.7161
# Epoch 877/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7598e-04 - val_loss: 0.7166
# Epoch 878/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7971e-04 - val_loss: 0.7163
# Epoch 879/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7457e-04 - val_loss: 0.7165
# Epoch 880/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7561e-04 - val_loss: 0.7164
# Epoch 881/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7251e-04 - val_loss: 0.7166
# Epoch 882/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7217e-04 - val_loss: 0.7165
# Epoch 883/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7009e-04 - val_loss: 0.7166
# Epoch 884/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6907e-04 - val_loss: 0.7166
# Epoch 885/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6747e-04 - val_loss: 0.7167
# Epoch 886/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6615e-04 - val_loss: 0.7167
# Epoch 887/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6477e-04 - val_loss: 0.7168
# Epoch 888/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6334e-04 - val_loss: 0.7168
# Epoch 889/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6203e-04 - val_loss: 0.7169
# Epoch 890/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6058e-04 - val_loss: 0.7169
# Epoch 891/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5928e-04 - val_loss: 0.7170
# Epoch 892/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5784e-04 - val_loss: 0.7170
# Epoch 893/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5653e-04 - val_loss: 0.7171
# Epoch 894/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5513e-04 - val_loss: 0.7171
# Epoch 895/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5379e-04 - val_loss: 0.7172
# Epoch 896/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5242e-04 - val_loss: 0.7172
# Epoch 897/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5106e-04 - val_loss: 0.7173
# Epoch 898/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4971e-04 - val_loss: 0.7173
# Epoch 899/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4834e-04 - val_loss: 0.7174
# Epoch 900/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4700e-04 - val_loss: 0.7174
# Epoch 901/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4563e-04 - val_loss: 0.7175
# Epoch 902/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4430e-04 - val_loss: 0.7175
# Epoch 903/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4293e-04 - val_loss: 0.7176
# Epoch 904/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4160e-04 - val_loss: 0.7176
# Epoch 905/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4024e-04 - val_loss: 0.7177
# Epoch 906/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3890e-04 - val_loss: 0.7177
# Epoch 907/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3755e-04 - val_loss: 0.7177
# Epoch 908/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3620e-04 - val_loss: 0.7178
# Epoch 909/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3486e-04 - val_loss: 0.7178
# Epoch 910/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3351e-04 - val_loss: 0.7179
# Epoch 911/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3217e-04 - val_loss: 0.7179
# Epoch 912/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3082e-04 - val_loss: 0.7180
# Epoch 913/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2949e-04 - val_loss: 0.7180
# Epoch 914/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2814e-04 - val_loss: 0.7181
# Epoch 915/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2680e-04 - val_loss: 0.7181
# Epoch 916/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2546e-04 - val_loss: 0.7181
# Epoch 917/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2412e-04 - val_loss: 0.7182
# Epoch 918/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2278e-04 - val_loss: 0.7182
# Epoch 919/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2143e-04 - val_loss: 0.7183
# Epoch 920/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2010e-04 - val_loss: 0.7183
# Epoch 921/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1876e-04 - val_loss: 0.7183
# Epoch 922/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1743e-04 - val_loss: 0.7184
# Epoch 923/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1608e-04 - val_loss: 0.7184
# Epoch 924/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1475e-04 - val_loss: 0.7185
# Epoch 925/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1341e-04 - val_loss: 0.7185
# Epoch 926/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1208e-04 - val_loss: 0.7185
# Epoch 927/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1074e-04 - val_loss: 0.7186
# Epoch 928/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0940e-04 - val_loss: 0.7186
# Epoch 929/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0807e-04 - val_loss: 0.7186
# Epoch 930/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0673e-04 - val_loss: 0.7187
# Epoch 931/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0541e-04 - val_loss: 0.7187
# Epoch 932/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0406e-04 - val_loss: 0.7188
# Epoch 933/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0274e-04 - val_loss: 0.7188
# Epoch 934/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0139e-04 - val_loss: 0.7188
# Epoch 935/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0007e-04 - val_loss: 0.7189
# Epoch 936/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9873e-04 - val_loss: 0.7189
# Epoch 937/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9740e-04 - val_loss: 0.7189
# Epoch 938/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9607e-04 - val_loss: 0.7190
# Epoch 939/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9473e-04 - val_loss: 0.7190
# Epoch 940/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9342e-04 - val_loss: 0.7190
# Epoch 941/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9206e-04 - val_loss: 0.7191
# Epoch 942/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.9076e-04 - val_loss: 0.7191
# Epoch 943/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8939e-04 - val_loss: 0.7191
# Epoch 944/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8810e-04 - val_loss: 0.7192
# Epoch 945/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8674e-04 - val_loss: 0.7192
# Epoch 946/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8543e-04 - val_loss: 0.7192
# Epoch 947/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8410e-04 - val_loss: 0.7193
# Epoch 948/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8276e-04 - val_loss: 0.7193
# Epoch 949/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8147e-04 - val_loss: 0.7193
# Epoch 950/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8008e-04 - val_loss: 0.7193
# Epoch 951/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7884e-04 - val_loss: 0.7194
# Epoch 952/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7740e-04 - val_loss: 0.7194
# Epoch 953/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7620e-04 - val_loss: 0.7194
# Epoch 954/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7475e-04 - val_loss: 0.7195
# Epoch 955/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7353e-04 - val_loss: 0.7195
# Epoch 956/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7212e-04 - val_loss: 0.7195
# Epoch 957/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7084e-04 - val_loss: 0.7195
# Epoch 958/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6954e-04 - val_loss: 0.7196
# Epoch 959/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6812e-04 - val_loss: 0.7196
# Epoch 960/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6698e-04 - val_loss: 0.7196
# Epoch 961/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6538e-04 - val_loss: 0.7197
# Epoch 962/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6442e-04 - val_loss: 0.7197
# Epoch 963/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6266e-04 - val_loss: 0.7198
# Epoch 964/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6182e-04 - val_loss: 0.7197
# Epoch 965/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6001e-04 - val_loss: 0.7198
# Epoch 966/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5914e-04 - val_loss: 0.7197
# Epoch 967/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5747e-04 - val_loss: 0.7199
# Epoch 968/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5633e-04 - val_loss: 0.7198
# Epoch 969/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5508e-04 - val_loss: 0.7199
# Epoch 970/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5339e-04 - val_loss: 0.7198
# Epoch 971/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5280e-04 - val_loss: 0.7199
# Epoch 972/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5035e-04 - val_loss: 0.7200
# Epoch 973/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5058e-04 - val_loss: 0.7199
# Epoch 974/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4734e-04 - val_loss: 0.7202
# Epoch 975/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4828e-04 - val_loss: 0.7198
# Epoch 976/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4456e-04 - val_loss: 0.7204
# Epoch 977/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4575e-04 - val_loss: 0.7196
# Epoch 978/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4223e-04 - val_loss: 0.7206
# Epoch 979/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4284e-04 - val_loss: 0.7196
# Epoch 980/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4048e-04 - val_loss: 0.7207
# Epoch 981/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3936e-04 - val_loss: 0.7196
# Epoch 982/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3924e-04 - val_loss: 0.7207
# Epoch 983/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3523e-04 - val_loss: 0.7198
# Epoch 984/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3827e-04 - val_loss: 0.7205
# Epoch 985/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3062e-04 - val_loss: 0.7203
# Epoch 986/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3738e-04 - val_loss: 0.7199
# Epoch 987/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2628e-04 - val_loss: 0.7211
# Epoch 988/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3688e-04 - val_loss: 0.7190
# Epoch 989/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2378e-04 - val_loss: 0.7222
# Epoch 990/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3801e-04 - val_loss: 0.7178
# Epoch 991/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2555e-04 - val_loss: 0.7238
# Epoch 992/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4302e-04 - val_loss: 0.7163
# Epoch 993/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3438e-04 - val_loss: 0.7256
# Epoch 994/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5504e-04 - val_loss: 0.7145
# Epoch 995/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5315e-04 - val_loss: 0.7278
# Epoch 996/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7829e-04 - val_loss: 0.7124
# Epoch 997/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8546e-04 - val_loss: 0.7304
# Epoch 998/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1984e-04 - val_loss: 0.7098
# Epoch 999/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3900e-04 - val_loss: 0.7339
# Epoch 1000/1000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9437e-04 - val_loss: 0.7063
# Training time (s) for 1000 epochs: 141.93528246879578

# %% [markdown]
# ### Question 3

# %%
# add code here to see what happens to the energy when we swap the two hydrogen atoms
# add code here to see what happens to the energy when we swap the two hydrogen atoms
test_config = configs_train[0] # Use the first structure from the training set

r_oh1_orig = test_config.get_distance(0, 1)
r_oh2_orig = test_config.get_distance(0, 2)
angle_orig = test_config.get_angle(1, 0, 2)

x_orig_inv = np.array([[r_oh1_orig, r_oh2_orig, angle_orig]])
x_orig_tf = tf.constant(x_orig_inv, dtype=tf.float64)

# Calculate swapped invariant descriptor: (r_OH2, r_OH1, angle)
x_swap_inv = np.array([[r_oh2_orig, r_oh1_orig, angle_orig]])
x_swap_tf = tf.constant(x_swap_inv, dtype=tf.float64)

# compare energies
y_orig_relative = model_invariant.predict(x_orig_tf, verbose=0)
y_swap_relative = model_invariant.predict(x_swap_tf, verbose=0)

y_orig_abs = y_orig_relative.item() + average_energy
y_swap_abs = y_swap_relative.item() + average_energy

print(f"Original energy (r_OH1, r_OH2): {y_orig_abs:.6f} eV")
print(f"Swapped energy (r_OH2, r_OH1): {y_swap_abs:.6f} eV")
print(f"Energy difference [eV]: {np.abs(y_orig_abs - y_swap_abs):.6e}")
# Out:
# Original energy (r_OH1, r_OH2): -2069.883523 eV
# Swapped energy (r_OH2, r_OH1): -2070.027748 eV
# Energy difference [eV]: 1.442255e-01

# %% [markdown]
# # Exercise 3: Computational cost versus accuracy

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Answer the following questions using the code below:</b> <br>
# <ol type='1'>
# <li> What is the effect of the network layout/size on the training and model performance? Do you notice underfitting/overfitting? Why should you not make your models too large?</li>
# <br>
# <li> What is the effect of the training set size on the training and model performance?</li>
# </ol>
# </div>

# %% [markdown]
# As you have seen the computational cost of a forward pass is determined by the size of your model (# of parameters), because this directly relates to the numbers of tensor operations that the model performs. Importantly, the number of tunable weights in the neural network will also determine the expressivity and transferability of your model. More weights means more freedom of the model to fit the training set accurately.
#
# Beware of too much freedom, however!

# %% [markdown]
# ### Question 1

# %%
# SMALL MODEL

# %%
# LARGE MODEL

# %% [markdown]
# ### Question 2

# %% [markdown]
# # Exercise 4: Incorporating permutation invariance and forces

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>In short:</b> <br>
#     1. Construct a neural network that respects permutation invariance  <br>
#     2. Incorporate the ability to calculate forces <br>
#     3. Perform optimizations and MD simulations using your own neural network
# </div>

# %% [markdown]
# ### Permutation invariance
#
# Another fundamental physical invariance is permutation invariance, i.e. swapping two identical atoms (2 H atoms) will not change the total energy of the system. Up until now, our descriptors have depended on the order of the atoms in the input. Permuation invariance can be explicitly incorporated by, instead of predicting one total energy, we predict fictional 'per-atom energies' for each atom and sum them all together to obtain the total energy. It is clear that the explicit permutation invariance is inherited from the commutativity of the sum. These per-atom energies are unphysical, but their individual values are irrelevant, the only thing that matters is how they sum together.
#
# **NOTE:** the per-atom energies mentioned here are entirely unrelated to the energies of the isolated atoms.
#
# To get atomic energies, we need an input feature (descriptor) for each atom individually. In general, this atomic descriptor should contain all of the information necessary to describe the (local) chemical environment of that specific atom. We can then pass these atomic features one by one through a single shared model and sum all of their energies together to obtain the total energy of the structure. This is schematically shown in Figure 4. In a permutation invariant model it is important that the atomic feature also contains information on the type of atom, otherwise the model will think that each atom is identical. For a specific atom, we can define the atomic descriptor as the distances between that atom and the other two atoms, and extend it with a one-hot encoding vector to account for the atomic species $(O = [0, 1], H = [1, 0])$.
#
# <figure>
# <center><img src="https://www.dropbox.com/scl/fi/xqsdlzzgkeg806lldu7wh/energy_readouts.png?rlkey=0b1lo9zvn0vn72mz46oi4cdly&st=b46bd8zo&raw=1" width="700"></center>
# <center><figcaption>Figure 3: Schematic representation a permutation invariant MLP, atomic energies are calculated through the same model and summed to obtain the total energy.</figcaption></center>
# </figure>

# %% [markdown]
# ### Forces
#
# Neural networks are usually trained using a technique called **backpropagation**. In this algorithm, the gradient of the loss function w.r.t. the model weights is efficiently calculated using the chain rule of calculus. The prediction error is propagated backwards through the network to determine how to tweak the weights and biases to minimize the error. In practice, this is enabled by the built-in **automatic differentiation** implemented in TensorFlow. All tensor operations are (at least once) continuously differentiable, such that the entire network is actually a non-linear analytic function that can be differentiated, if all intermediate information is stored after a forward pass. Fortunately for us, this automatic differentiation can also be used to calculate the forces acting on the atoms, as this is simply the **negative** gradient of the energy w.r.t. the positions. The forces acting on atom $i$ are given by
#
# $ \vec{F_i} = -(\frac{\partial E}{\partial x_i}, \frac{\partial E}{\partial y_i}, \frac{\partial E}{\partial z_i}) $.
#
# Therefore, we automatically have forces, as long as each operation from atomic positions to total energy is differentiable, which is the case for (most of) the TensorFlow tensor operations.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Activation functions</b>
#
# Activation functions are non-linear functions that are applied to the weights of each layer. It is precisely this non-linearity that allows the model to learn complex relations between input and output. Importantly, not all activation functions are actually continuously differentiable, for example the well known ReLU function. For this reason, we have mainly used the swish activation function which is basically a smoother version of ReLU and yields better gradients for training and forces.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Answer the following questions using the code below:</b> <br>
# <ol type='1'>
# <li> Train a model with this new architecture and use it to optimize some structures from the training set. What are the optimized bonds, angles?</li>
# <br>
# <li> Perform some NVT simulations at room temperature. Visualise the trajectory and plot the bond lengths, angles, does this look realistic to you?</li>
# <br>
# <li> Can you get a measure of how much more efficient this neural network potential is in comparison to DFT calculations on a water molecule?</li>
# </div>

# %%
from tensorflow.keras import saving

# normalization of the pair-wise distances
def get_mean_std(input):
    descriptor_layer = StablePairwiseDistancesWithSpecies()
    desc = descriptor_layer(input)
    distances = desc[:, :, :2]
    d_mean = tf.reduce_mean(distances, axis=[0,1])
    d_std = tf.math.reduce_std(distances, axis=[0,1])

    return d_mean, d_std

@saving.register_keras_serializable()
class CustomNormalization(tf.keras.layers.Layer):
    def __init__(self, mean, std, **kwargs):
        super(CustomNormalization, self).__init__(**kwargs)
        self.mean = tf.constant(mean, dtype=tf.float64)
        self.std = tf.constant(std, dtype=tf.float64)
        
    def call(self, inp):
        distances = inp[:, :2]
        onehot = inp[:, 2:]
        d_norm = (distances - self.mean) / self.std
        return tf.concat([d_norm, onehot], axis=-1)

    def get_config(self):
        config = super().get_config()
        # You must convert tensors to lists for serialization
        config.update({
            "mean": self.mean.numpy().tolist(),
            "std": self.std.numpy().tolist(),
        })
        return config

    @classmethod
    def from_config(cls, config):
        # Keras will pass mean/std back as lists
        return cls(**config)

@saving.register_keras_serializable()
class StablePairwiseDistancesWithSpecies(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(StablePairwiseDistancesWithSpecies, self).__init__(**kwargs)

    def call(self, coords):
        """
        coords: (B, N, 3)
        returns: (B, N, N-1)
        """
        B = tf.shape(coords)[0]
        N = tf.shape(coords)[1]

        # Compute pairwise vectors: (B, N, N, 3)
        diff = coords[:, :, None, :-1] - coords[:, None, :, :-1]

        # Pairwise distances: (B, N, N)
        dist_mat = tf.norm(diff, axis=-1)

        # Create a diagonal mask: (N, N)
        diag_mask = ~tf.eye(N, dtype=tf.bool)

        # Broadcast mask to (B, N, N)
        diag_mask = tf.broadcast_to(diag_mask, tf.shape(dist_mat))

        # Mask out the diagonal, flatten to (B, N*(N-1))
        flat = tf.boolean_mask(dist_mat, diag_mask)

        # Reshape to (B, N, N-1)
        res = tf.reshape(flat, (B, N, N - 1))

        species = coords[:, :, -1]
        # one hot encode species
        species = keras.layers.CategoryEncoding(num_tokens=2, output_mode='one_hot')(tf.cast(species, tf.int32))
        # add columns in dists for species
        desc = tf.concat([res, species[:, :, 0:1], species[:, :, 1:2]], axis=-1)

        return desc

@saving.register_keras_serializable()
class SumLayer(tf.keras.layers.Layer):
    def __init__(self, axis=1, **kwargs):
        super().__init__(**kwargs)
        self.axis = axis

    def call(self, inputs):
        return tf.reduce_sum(inputs, axis=self.axis)

    def get_config(self):
        config = super().get_config()
        config.update({"axis": self.axis})
        return config

# %% [markdown]
# ### Question 1

# %% [markdown]
# In this model, we want to explicitly encode the atom species into the descriptor, such that the model does not have to learn this itself. The input tensor of the model must now be structured in a way that includes the atomic number of each atom to be evaluated. The model input will be the position vector of the three atoms, extended with the atomic number of that atom. However, the atomic number can be high and neural networks do not like this. We will therefore use $0$ for the oxygen atoms and $1$ for the hydrogen atoms. Such that for a single structure, the input tensor $\textbf{I}$ has shape (3, 4) and should look like:
#
# \begin{equation}
# \textbf{I} =
# \begin{bmatrix}
# x_1 & y_1 & z_1 & \alpha_1 \\
# x_2 & y_2 & z_2 & \alpha_2 \\
# x_3 & y_3 & z_3 & \alpha_3 \\
# \end{bmatrix},
# \end{equation} where $\alpha = {0, 1}$.
#
# We have prepared some custom layers to transform this input tensor into a good descriptor for the model.
#
# **HINT:** the atomic numbers can be extracted using `Atoms.get_atomic_numbers()` or `Atom.number`:
#
# ```python
# atomic_number1 = water.get_atomic_numbers()[0]
# alpha1 = numbers2type[atomic_number1]
# ```
#
# or
#
# ```python
# atomic_number1 = water[0].number
# alpha1 = numbers2type[atomic_number1]
# ```

# %%
B_train = len(configs_train)
B_valid = len(configs_valid)
N = 3

#
x_train = np.ones((B_train, N, 4)) # (B, N, 3 + 1 for atom number)
y_train_absolute = np.ones((B_train, 1))

x_valid = np.ones((B_valid, N, 4))
y_valid_absolute = np.ones((B_valid, 1))

numbers2type = {8: 0, 1: 1}  # O:0, H:1

#training
for i, config in enumerate(configs_train):
    x_train[i, :, :3] = config.get_positions()

    x_train[i, :, 3] = [numbers2type[atom.number] for atom in config] # add atom types
    y_train_absolute[i] = config.get_potential_energy()

#validation
for i, config in enumerate(configs_valid):
    x_valid[i, :, :3] = config.get_positions()
    x_valid[i, :, 3] = [numbers2type[atom.number] for atom in config]
    y_valid_absolute[i] = config.get_potential_energy()

average_energy = np.mean(y_train_absolute)
y_train = y_train_absolute - average_energy
y_valid = y_valid_absolute - average_energy

x_train_tf = tf.constant(x_train, dtype=tf.float64)
y_train_tf = tf.constant(y_train, dtype=tf.float64)
x_valid_tf = tf.constant(x_valid, dtype=tf.float64)
y_valid_tf = tf.constant(y_valid, dtype=tf.float64)

print(f"Data preparation complete. Average Energy: {average_energy:.6f} eV")
# Out:
# Data preparation complete. Average Energy: -2069.638504 eV

# %%
mean, std = get_mean_std(x_train)
print("Distance mean:", mean.numpy())
print("Distance std:", std.numpy())
input_shape = (3, 4)
model3 = keras.Sequential()

model3.add(keras.layers.Input(shape=input_shape))
model3.add(StablePairwiseDistancesWithSpecies())
hidden_layers = keras.Sequential([
    keras.layers.Input(shape=(4,)),
    CustomNormalization(mean, std),
    keras.layers.Dense(10, activation='swish', kernel_initializer=hidden_initializer),
    keras.layers.Dense(10, activation='swish', kernel_initializer=hidden_initializer),
    keras.layers.Dense(1, activation='linear', kernel_initializer=output_initializer),
])

model3.add(keras.layers.TimeDistributed(hidden_layers))
sum_layer = SumLayer()
model3.add(sum_layer)
print(model3.summary())
# Out:
# Distance mean: [1.00899277 1.37936284]
# Distance std: [0.15663879 0.36118713]
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ stable_pairwise_distances_with… │ (None, 3, 4)           │             0 │
# │ (StablePairwiseDistancesWithSp… │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 3, 1)           │           171 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sum_layer_1 (SumLayer)          │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 171 (1.34 KB)
#  Trainable params: 171 (1.34 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# add code here to train model

epochs = 1000 
model3 = train_model(model3, x_train_tf, y_train_tf, x_valid_tf, y_valid_tf, learning_rate=1e-3, epochs=epochs)
print("Model training completed.")

# %%
model_path = "session9/mlp_invariant_forces.keras"
model3.save(model_path)

# %% [markdown]
# Our entire neural network, from input (positions) to output (energy), is fully automatically differentiable. Therefore, we can now calculate the forces by computing the gradient of the energy w.r.t. the atomic coordinates. In TensorFlow, this is done like this:
#
# ```python
# input_tensor = tf.Variable(input_tensor, dtype=tf.float64)  # Shape: (1, 3, 4). This tells TensorFlow to store intermediate results for the gradient computation
# with tf.GradientTape() as tape:
#     energy_prediction = model(input_tensor)
# gradients = -tape.gradient(energy_prediction, input_tensor) # (1, 3, 4) shaped tensor containing gradients.
# ```
#
# By ignoring the last column, we obtain the three force components acting on each atom:
#
# ```python
# forces = gradients[:, :, :-1]
# ```

# %% [markdown]
# ### ASE Calculator
# By creating a minimal ASE Calculator for our neural network potential, we can couple our energy and force calculations to ASE. This allows us to interface with the optimization and molecular dynamics functions from ASE.

# %%
from ase.calculators.calculator import Calculator, all_changes
from ase import Atoms
from ase.parallel import broadcast, world
class NNPCalculator(Calculator):
    """
    ASE Calculator wrapper to calculate energies and forces using a simple neural network potential.
    """
    implemented_properties = ['energy', 'forces']

    def __init__(self, model, atoms: Atoms = None):
        self.istep = 0
        Calculator.__init__(self, atoms=atoms)
        self.model = model

    def _get_name(self):
        return 'NNP'

    def calculate(self, atoms: Atoms = None, properties: list[str] = ['energy', 'forces'], system_changes=all_changes):
        Calculator.calculate(self, atoms, properties, system_changes)

        positions = atoms.get_positions()
        comp = self.compute_energy_and_forces(positions, self.istep)
        energy, forces = comp
        self.istep += 1
        self.results['energy'] = energy
        self.results['forces'] = forces[:, :3]

    def compute_energy_and_forces(self, pos, istep):
        input_tensor = np.zeros((1, pos.shape[1], 4), dtype=np.float64)
        input_tensor[0, :, :-1] = pos
        numbers2type = {8: 0, 1: 1}  # O:0, H:1
        input_tensor[0, :, -1] = np.array([numbers2type[atom.number] for atom in self.atoms])
        pos = tf.Variable(input_tensor, dtype=tf.float64)
        if world.rank == 0:
            with tf.GradientTape() as tape:
                energy_pred = self.model(pos) 
            forces_pred = -tape.gradient(energy_pred, pos)
            ener_force = (energy_pred.numpy().squeeze(), forces_pred.numpy().squeeze())
        else:
           ener_force = None
        energy, forces = broadcast(ener_force)
        return energy, forces

    def __enter__(self):
        return self

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>ASE calculators</b>
#
# An `ase.Atoms`-object can have a `calc`-attribute which computes (at least) the energy and forces used for optimisations, MD, etc. In our case, we have made a custom ASE calculator (`NNPCalculator`) that can compute the energy and forces through our own neural network. Calculators can be attached to `ase.Atoms`-objects as follows:
#
# ```python
# model = load_model('path/to/model')
# calculator = NNPCalculator(model)
# config = read('path/to/some/config')   # Atoms object
# config.calc = calculator
# ```
#
# Then `config` can be used for optimisations or MD.
# </div>

# %% [markdown]
# Use the `BFGS`-optimizer from ASE to optimize structures from the test set, for more information check the [manual](https://ase-lib.org/ase/optimize.html#ase.optimize.BFGS).

# %%
from ase.optimize import BFGS

def optimize(config, calculator, fmax=1e-4):
    config.calc = calculator
    
    dyn = BFGS(config, trajectory='opt_nnp.traj', logfile='opt_nnp.log')
    
    dyn.run(fmax=fmax)
    
    r_oh1 = config.get_distance(0, 1)
    r_oh2 = config.get_distance(0, 2)
    angle = config.get_angle(1, 0, 2)
    
    print("\n--- Optimized Geometry Results (NNP) ---")
    print(f"O-H1 distance: {r_oh1:.4f} Å")
    print(f"O-H2 distance: {r_oh2:.4f} Å")
    print(f"H-O-H angle: {angle:.2f} degrees")
    print(f"Final Energy: {config.get_potential_energy():.6f} eV")
    
    return config

# %% [markdown]
# ### Question 2

# %% [markdown]
# Use the MD engine in ASE to perform a short 500 fs MD simulation in the NVT ensemble at 300 K with a water molecule, for more information see the [manual](https://ase-lib.org/ase/md.html#module-ase.md.langevin)

# %%
from ase.md.langevin import Langevin
from ase.units import kB, fs

def nvt(config, calculator, steps=1000, temperature=300, n_print=10, timestep=0.5*fs):
    config.calc = calculator
    config.set_velocities(np.sqrt(2 * kB * temperature / config.get_masses()))
    
    dyn = Langevin(
        config, 
        timestep=timestep,      
        temperature=temperature * kB, 
        friction=0.002,        
        trajectory='md_nnp.traj',
        loginterval=n_print
    )
    
    dyn.run(steps=steps)

    return config

def plot_md_results(trajectory_file='md_nnp.traj', save_step = 10, timestep = 0.5*fs):
    
    traj = read(trajectory_file, index=':')
        
    steps = np.arange(len(traj))
    time = steps*timestep*save_step
    
    distances_h1 = [atom.get_distance(0, 1) for atom in traj]
    distances_h2 = [atom.get_distance(0, 2) for atom in traj]
    angles = [atom.get_angle(1, 0, 2) for atom in traj]
    
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    
    # distances
    axs[0].plot(time, distances_h1, color=red, label='O-H1', alpha=0.7)
    axs[0].plot(time, distances_h2, color=blue, label='O-H2', alpha=0.7)
    axs[0].set_ylabel('Distance [Å]')
    axs[0].legend(frameon=False)
    
    # angle
    axs[1].plot(time, angles, label='H-O-H Angle', color=green)
    axs[1].set_ylabel('Angle [degrees]')
    axs[1].set_xlabel('Time [fs]')
    axs[1].legend(frameon=False)

    axs[0].tick_params(axis='x', which='both', top=True, direction='in')
    axs[0].tick_params(axis='y', which='both', right=True, direction='in')

    axs[1].tick_params(axis='x', which='both', top=True, direction='in')
    axs[1].tick_params(axis='y', which='both', right=True, direction='in')
    
    plt.tight_layout()
    #plt.savefig('md_nnp_results.png')
    plt.show()

# %%
initial_config = configs_train[0].copy() 
nnp_calculator = NNPCalculator(model_loaded) 
final_config = nvt(initial_config, nnp_calculator, steps=5000)

# %%
plot_md_results('md_nnp.traj')

# %% [markdown]
# ### Question 3
